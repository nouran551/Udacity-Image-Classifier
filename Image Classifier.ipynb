# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch import tensor
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms
import torchvision.models as models
import argparse
from collections import OrderedDict
import json
import PIL
import seaborn as sns
from PIL import Image
import time

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets

#The transform RandomResizedCrop crops the input image by a random size.
#RandomHorizontalFlip randomly flips the image horizontally with a default probability of 50%.
#CenterCrop crops an 224×224 image from the center.
#Normalize takes in a 3 channel Tensor and normalizes each channel by the input mean and standard deviation for the channel.
#and Each channel in the tensor is normalized as T = (T – mean)/(standard deviation)
#All the above transformations are chained together using Compose.
#Note that for the validation and test data, do not do the RandomResizedCrop and RandomHorizontalFlip transformations. 
#Instead,we just resize the validation images and crop out the center in order to be able to use them with the pretrained model.

data_transforms = { 
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ])
}

# TODO: Load the datasets with ImageFolder
image_datasets = {
    'train': datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'valid': datasets.ImageFolder(valid_dir, transform=data_transforms['valid']),
    'test': datasets.ImageFolder(test_dir, transform=data_transforms['test'])
}




# TODO: Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=64, shuffle=True)
validation_loader = torch.utils.data.DataLoader(image_datasets['valid'], batch_size =64,shuffle = True)
test_loader = torch.utils.data.DataLoader(image_datasets['test'], batch_size = 64, shuffle = True)

# Size of Loaders, to be used for calculating Average Loss and Accuracy
train_Loader_size = len(train_loader)
valid_Loader_size = len(validation_loader)
test_loader_size = len(test_loader)


# Print the train, validation and test set data sizes
train_Loader_size, valid_Loader_size, test_loader_size
# Out:
# (103, 13, 13)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network

# Load pretrained vgg16 Model
#vgg16 have several advantages: It has so many weight parameters, the models are very heavy, 550 MB + of weight size, 
#Which also means long inference time
#source (https://forums.fast.ai/t/vgg-strength-and-limitations/1218)

model = models.vgg16(pretrained=True)

#When a model is loaded in PyTorch, all its parameters have their ‘requires_grad‘ field set to true by default. 
#That means each and every change to the parameter values will be stored in order to be used in the back propagation graph 
#used for training. This increases memory requirements. So,
#since most of the parameters in our pre-trained model are already trained for us, we reset the requires_grad field to false.

#to freeze part of the convolutional part of vgg16 model and train the rest
for param in model.parameters():
    param.requires_grad = False
        
#Then we replace the final layer of the vgg16 model by a small set of Sequential layers. 
#The inputs to the last fully connected layer of vgg16 is fed to a Linear layer, 
#which are then fed into ReLU (rectified linear unit) and Dropout layers.


#Used OrderedDict to preserve the order in which the keys are inserted
from collections import OrderedDict

classifier = nn.Sequential(OrderedDict([
            ('inputs', nn.Linear(25088, 120)), #hidden layer 1 sets output to 120
            ('relu1', nn.ReLU()),
            ('dropout',nn.Dropout(0.5)), #could use a different droupout probability,but 0.5 usually works well
            ('hidden_layer1', nn.Linear(120, 90)), #hidden layer 2 output to 90
            ('relu2',nn.ReLU()),
            ('hidden_layer2',nn.Linear(90,70)), #hidden layer 3 output to 70
            ('relu3',nn.ReLU()),
            ('hidden_layer3',nn.Linear(70,102)),#output size = 102
            ('output', nn.LogSoftmax(dim=1))]))# For using NLLLoss()
   
model.classifier = classifier
        
#Since we will be doing the training on a GPU, we get the model ready for GPU.

# Convert model to be used on GPU
if torch.cuda.is_available():
    model.cuda()

#define the criterion and the optimizer to be used for training.
#Negative Loss Likelihood function(NLLLoss()) as it can be used for classifying multiple classes.
#Adam is one the most popular optimizers because it can adapt the learning rate for each parameter individually.

criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:10<00:00, 53388804.49it/s]

# %%
#Training is carried out for a fixed set of epochs, processing each image once in a single epoch.
#The training data loader loads data in batches.
#In our case, we have given a batch size of 64, which means each batch can have at most 64 images.

#with transfer learning, we need to compute gradients only for a small set of parameters 
#that belong to the few newly added layers towards the end of the model.

#Gradient computation is done using the autograd and back propagation.
#PyTorch accumulates all the gradients in the backward pass. 
# So it is essential to zero them out at the beginning of the training loop.
#This is achieved using the optimizer’s zero_grad function.

#Finally, after the gradients are computed in the backward pass, the parameters are updated using the optimizer’s step function.

#Total loss and accuracy is computed for the whole batch, 
#which is then averaged over all the batches to get the loss and accuracy values for the whole epoch.

epochs=18
for epoch in range(epochs):
    print("Epoch: {}/{}".format(epoch+1, epochs))
     
# tell the model that you are training . So effectively layers like dropout, batchnorm etc,
#which behave different on the train and test procedures know what is going on and hence can behave accordingly.
# Set to training mode    
    # Set to training mode
    model.train()
     
    # Loss and Accuracy within the epoch
    train_loss = 0.0
    train_acc = 0.0
     
    valid_loss = 0.0
    valid_acc = 0.0
 
    for i, (inputs, labels) in enumerate(train_loader):
 
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
         
        # Clean existing gradients
        optimizer.zero_grad()
         
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
         
        # Compute loss
        loss = criterion(outputs, labels)
         
        # Backpropagate the gradients
        loss.backward()
         
        # Update the parameters
        optimizer.step()
         
        # Compute the total loss for the batch and add it to train_loss
        train_loss += loss.item() * inputs.size(0)
         
        # Compute the accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
         
        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
         
        # Compute total accuracy in the whole batch and add to train_acc
        train_acc += acc.item() * inputs.size(0)
         
        print("Batch no: {:03d}, Loss on trainig: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))
# Out:
# Epoch: 1/18
# Batch no: 000, Loss on trainig: 4.6314, Accuracy: 0.0000
# Batch no: 001, Loss on trainig: 4.6491, Accuracy: 0.0000
# Batch no: 002, Loss on trainig: 4.5881, Accuracy: 0.0000
# Batch no: 003, Loss on trainig: 4.6597, Accuracy: 0.0000
# Batch no: 004, Loss on trainig: 4.5951, Accuracy: 0.0000
# Batch no: 005, Loss on trainig: 4.6500, Accuracy: 0.0156
# Batch no: 006, Loss on trainig: 4.6152, Accuracy: 0.0156
# Batch no: 007, Loss on trainig: 4.5447, Accuracy: 0.0156
# Batch no: 008, Loss on trainig: 4.5470, Accuracy: 0.0156
# Batch no: 009, Loss on trainig: 4.5619, Accuracy: 0.0469
# Batch no: 010, Loss on trainig: 4.5272, Accuracy: 0.0156
# Batch no: 011, Loss on trainig: 4.6273, Accuracy: 0.0312
# Batch no: 012, Loss on trainig: 4.5950, Accuracy: 0.0469
# Batch no: 013, Loss on trainig: 4.5699, Accuracy: 0.0156
# Batch no: 014, Loss on trainig: 4.5900, Accuracy: 0.0312
# Batch no: 015, Loss on trainig: 4.5764, Accuracy: 0.0625
# Batch no: 016, Loss on trainig: 4.5649, Accuracy: 0.0000
# Batch no: 017, Loss on trainig: 4.3402, Accuracy: 0.0469
# Batch no: 018, Loss on trainig: 4.5318, Accuracy: 0.0156
# Batch no: 019, Loss on trainig: 4.5151, Accuracy: 0.0156
# Batch no: 020, Loss on trainig: 4.5085, Accuracy: 0.0312
# Batch no: 021, Loss on trainig: 4.4817, Accuracy: 0.0469
# Batch no: 022, Loss on trainig: 4.4966, Accuracy: 0.0781
# Batch no: 023, Loss on trainig: 4.4398, Accuracy: 0.0781
# Batch no: 024, Loss on trainig: 4.3620, Accuracy: 0.1094
# Batch no: 025, Loss on trainig: 4.4724, Accuracy: 0.0312
# Batch no: 026, Loss on trainig: 4.3317, Accuracy: 0.1094
# Batch no: 027, Loss on trainig: 4.4178, Accuracy: 0.0625
# Batch no: 028, Loss on trainig: 4.2688, Accuracy: 0.1250
# Batch no: 029, Loss on trainig: 4.4090, Accuracy: 0.0625
# Batch no: 030, Loss on trainig: 4.3270, Accuracy: 0.0781
# Batch no: 031, Loss on trainig: 4.2372, Accuracy: 0.1094
# Batch no: 032, Loss on trainig: 4.1677, Accuracy: 0.0469
# Batch no: 033, Loss on trainig: 4.1432, Accuracy: 0.1094
# Batch no: 034, Loss on trainig: 4.2731, Accuracy: 0.1250
# Batch no: 035, Loss on trainig: 4.3806, Accuracy: 0.1250
# Batch no: 036, Loss on trainig: 4.2872, Accuracy: 0.0781
# Batch no: 037, Loss on trainig: 4.4264, Accuracy: 0.0781
# Batch no: 038, Loss on trainig: 4.2264, Accuracy: 0.1406
# Batch no: 039, Loss on trainig: 4.1319, Accuracy: 0.1406
# Batch no: 040, Loss on trainig: 4.2945, Accuracy: 0.0625
# Batch no: 041, Loss on trainig: 4.1362, Accuracy: 0.0469
# Batch no: 042, Loss on trainig: 4.0019, Accuracy: 0.1406
# Batch no: 043, Loss on trainig: 3.9311, Accuracy: 0.1562
# Batch no: 044, Loss on trainig: 4.2045, Accuracy: 0.1406
# Batch no: 045, Loss on trainig: 4.1297, Accuracy: 0.1094
# Batch no: 046, Loss on trainig: 3.9329, Accuracy: 0.1406
# Batch no: 047, Loss on trainig: 4.2204, Accuracy: 0.0938
# Batch no: 048, Loss on trainig: 4.4041, Accuracy: 0.0625
# Batch no: 049, Loss on trainig: 4.1338, Accuracy: 0.1094
# Batch no: 050, Loss on trainig: 4.1562, Accuracy: 0.0938
# Batch no: 051, Loss on trainig: 4.0148, Accuracy: 0.1250
# Batch no: 052, Loss on trainig: 3.9696, Accuracy: 0.1094
# Batch no: 053, Loss on trainig: 4.0993, Accuracy: 0.1094
# Batch no: 054, Loss on trainig: 4.0817, Accuracy: 0.1094
# Batch no: 055, Loss on trainig: 4.0953, Accuracy: 0.1719
# Batch no: 056, Loss on trainig: 3.8460, Accuracy: 0.1875
# Batch no: 057, Loss on trainig: 3.8549, Accuracy: 0.1562
# Batch no: 058, Loss on trainig: 3.9079, Accuracy: 0.1250
# Batch no: 059, Loss on trainig: 3.8943, Accuracy: 0.1094
# Batch no: 060, Loss on trainig: 3.8715, Accuracy: 0.1406
# Batch no: 061, Loss on trainig: 3.8743, Accuracy: 0.1719
# Batch no: 062, Loss on trainig: 3.8874, Accuracy: 0.1406
# Batch no: 063, Loss on trainig: 3.7168, Accuracy: 0.2031
# Batch no: 064, Loss on trainig: 3.9018, Accuracy: 0.1406
# Batch no: 065, Loss on trainig: 3.6470, Accuracy: 0.1250
# Batch no: 066, Loss on trainig: 3.8618, Accuracy: 0.1406
# Batch no: 067, Loss on trainig: 3.5137, Accuracy: 0.2031
# Batch no: 068, Loss on trainig: 3.4500, Accuracy: 0.2188
# Batch no: 069, Loss on trainig: 3.6078, Accuracy: 0.2031
# Batch no: 070, Loss on trainig: 3.8475, Accuracy: 0.1719
# Batch no: 071, Loss on trainig: 3.8241, Accuracy: 0.1875
# Batch no: 072, Loss on trainig: 3.5887, Accuracy: 0.1719
# Batch no: 073, Loss on trainig: 3.6209, Accuracy: 0.2031
# Batch no: 074, Loss on trainig: 3.1120, Accuracy: 0.2812
# Batch no: 075, Loss on trainig: 3.6289, Accuracy: 0.1719
# Batch no: 076, Loss on trainig: 3.5904, Accuracy: 0.2031
# Batch no: 077, Loss on trainig: 3.5753, Accuracy: 0.2188
# Batch no: 078, Loss on trainig: 3.6793, Accuracy: 0.1719
# Batch no: 079, Loss on trainig: 3.5486, Accuracy: 0.1875
# Batch no: 080, Loss on trainig: 3.9307, Accuracy: 0.1250
# Batch no: 081, Loss on trainig: 3.3832, Accuracy: 0.2656
# Batch no: 082, Loss on trainig: 3.3222, Accuracy: 0.2344
# Batch no: 083, Loss on trainig: 3.2966, Accuracy: 0.2500
# Batch no: 084, Loss on trainig: 3.4366, Accuracy: 0.2031
# Batch no: 085, Loss on trainig: 3.5223, Accuracy: 0.2031
# Batch no: 086, Loss on trainig: 3.5695, Accuracy: 0.1562
# Batch no: 087, Loss on trainig: 3.1347, Accuracy: 0.2656
# Batch no: 088, Loss on trainig: 3.1037, Accuracy: 0.2969
# Batch no: 089, Loss on trainig: 3.2009, Accuracy: 0.2500
# Batch no: 090, Loss on trainig: 3.3632, Accuracy: 0.1719
# Batch no: 091, Loss on trainig: 2.8361, Accuracy: 0.3281
# Batch no: 092, Loss on trainig: 3.3999, Accuracy: 0.2500
# Batch no: 093, Loss on trainig: 3.1741, Accuracy: 0.2188
# Batch no: 094, Loss on trainig: 3.1603, Accuracy: 0.2812
# Batch no: 095, Loss on trainig: 3.0998, Accuracy: 0.2812
# Batch no: 096, Loss on trainig: 2.8428, Accuracy: 0.3125
# Batch no: 097, Loss on trainig: 3.0691, Accuracy: 0.2812
# Batch no: 098, Loss on trainig: 3.4793, Accuracy: 0.1719
# Batch no: 099, Loss on trainig: 3.4625, Accuracy: 0.2031
# Batch no: 100, Loss on trainig: 2.9657, Accuracy: 0.2812
# Batch no: 101, Loss on trainig: 3.3228, Accuracy: 0.1719
# Batch no: 102, Loss on trainig: 2.8879, Accuracy: 0.3750
# Epoch: 2/18
# Batch no: 000, Loss on trainig: 3.0258, Accuracy: 0.2344
# Batch no: 001, Loss on trainig: 3.4467, Accuracy: 0.2344
# Batch no: 002, Loss on trainig: 2.9471, Accuracy: 0.2656
# Batch no: 003, Loss on trainig: 3.0254, Accuracy: 0.2344
# Batch no: 004, Loss on trainig: 2.9908, Accuracy: 0.2969
# Batch no: 005, Loss on trainig: 2.7299, Accuracy: 0.4062
# Batch no: 006, Loss on trainig: 2.8888, Accuracy: 0.2500
# Batch no: 007, Loss on trainig: 3.0569, Accuracy: 0.2812
# Batch no: 008, Loss on trainig: 2.9704, Accuracy: 0.2656
# Batch no: 009, Loss on trainig: 2.8391, Accuracy: 0.3125
# Batch no: 010, Loss on trainig: 3.1745, Accuracy: 0.2656
# Batch no: 011, Loss on trainig: 3.1778, Accuracy: 0.2500
# Batch no: 012, Loss on trainig: 2.8603, Accuracy: 0.2812
# Batch no: 013, Loss on trainig: 2.6398, Accuracy: 0.3438
# Batch no: 014, Loss on trainig: 2.4537, Accuracy: 0.4375
# Batch no: 015, Loss on trainig: 2.8758, Accuracy: 0.2812
# Batch no: 016, Loss on trainig: 3.0769, Accuracy: 0.2656
# Batch no: 017, Loss on trainig: 2.6913, Accuracy: 0.2812
# Batch no: 018, Loss on trainig: 2.6384, Accuracy: 0.2969
# Batch no: 019, Loss on trainig: 3.1547, Accuracy: 0.1875
# Batch no: 020, Loss on trainig: 3.0739, Accuracy: 0.2031
# Batch no: 021, Loss on trainig: 3.2789, Accuracy: 0.1719
# Batch no: 022, Loss on trainig: 2.9451, Accuracy: 0.3438
# Batch no: 023, Loss on trainig: 2.6883, Accuracy: 0.2812
# Batch no: 024, Loss on trainig: 2.6879, Accuracy: 0.3594
# Batch no: 025, Loss on trainig: 2.9081, Accuracy: 0.3438
# Batch no: 026, Loss on trainig: 2.6432, Accuracy: 0.3594
# Batch no: 027, Loss on trainig: 2.9713, Accuracy: 0.2344
# Batch no: 028, Loss on trainig: 2.8380, Accuracy: 0.2969
# Batch no: 029, Loss on trainig: 2.7107, Accuracy: 0.2500
# Batch no: 030, Loss on trainig: 2.9412, Accuracy: 0.2188
# Batch no: 031, Loss on trainig: 2.9744, Accuracy: 0.2656
# Batch no: 032, Loss on trainig: 2.6509, Accuracy: 0.2969
# Batch no: 033, Loss on trainig: 2.3903, Accuracy: 0.3594
# Batch no: 034, Loss on trainig: 2.6816, Accuracy: 0.2812
# Batch no: 035, Loss on trainig: 2.6152, Accuracy: 0.3438
# Batch no: 036, Loss on trainig: 2.9861, Accuracy: 0.2500
# Batch no: 037, Loss on trainig: 2.6694, Accuracy: 0.2812
# Batch no: 038, Loss on trainig: 2.7777, Accuracy: 0.3281
# Batch no: 039, Loss on trainig: 3.1614, Accuracy: 0.2344
# Batch no: 040, Loss on trainig: 2.8568, Accuracy: 0.2812
# Batch no: 041, Loss on trainig: 3.3093, Accuracy: 0.2188
# Batch no: 042, Loss on trainig: 2.6721, Accuracy: 0.3750
# Batch no: 043, Loss on trainig: 2.5412, Accuracy: 0.3125
# Batch no: 044, Loss on trainig: 2.6858, Accuracy: 0.3438
# Batch no: 045, Loss on trainig: 2.8053, Accuracy: 0.3438
# Batch no: 046, Loss on trainig: 2.7483, Accuracy: 0.2812
# Batch no: 047, Loss on trainig: 2.8191, Accuracy: 0.3125
# Batch no: 048, Loss on trainig: 2.4786, Accuracy: 0.3125
# Batch no: 049, Loss on trainig: 2.9897, Accuracy: 0.3281
# Batch no: 050, Loss on trainig: 2.8796, Accuracy: 0.3438
# Batch no: 051, Loss on trainig: 2.6843, Accuracy: 0.3750
# Batch no: 052, Loss on trainig: 2.4636, Accuracy: 0.3281
# Batch no: 053, Loss on trainig: 2.9818, Accuracy: 0.2500
# Batch no: 054, Loss on trainig: 2.6470, Accuracy: 0.2969
# Batch no: 055, Loss on trainig: 2.5431, Accuracy: 0.3281
# Batch no: 056, Loss on trainig: 2.8907, Accuracy: 0.1875
# Batch no: 057, Loss on trainig: 2.9170, Accuracy: 0.3281
# Batch no: 058, Loss on trainig: 2.8630, Accuracy: 0.2656
# Batch no: 059, Loss on trainig: 3.0625, Accuracy: 0.2188
# Batch no: 060, Loss on trainig: 2.3969, Accuracy: 0.4219
# Batch no: 061, Loss on trainig: 2.7148, Accuracy: 0.3438
# Batch no: 062, Loss on trainig: 2.7157, Accuracy: 0.2812
# Batch no: 063, Loss on trainig: 2.6924, Accuracy: 0.3438
# Batch no: 064, Loss on trainig: 2.5067, Accuracy: 0.2969
# Batch no: 065, Loss on trainig: 2.9670, Accuracy: 0.2188
# Batch no: 066, Loss on trainig: 2.2096, Accuracy: 0.4062
# Batch no: 067, Loss on trainig: 2.9575, Accuracy: 0.2656
# Batch no: 068, Loss on trainig: 2.7900, Accuracy: 0.3281
# Batch no: 069, Loss on trainig: 2.4590, Accuracy: 0.3750
# Batch no: 070, Loss on trainig: 2.7785, Accuracy: 0.3750
# Batch no: 071, Loss on trainig: 2.5923, Accuracy: 0.2969
# Batch no: 072, Loss on trainig: 2.6649, Accuracy: 0.3750
# Batch no: 073, Loss on trainig: 2.3225, Accuracy: 0.3750
# Batch no: 074, Loss on trainig: 2.6880, Accuracy: 0.2656
# Batch no: 075, Loss on trainig: 2.3338, Accuracy: 0.4531
# Batch no: 076, Loss on trainig: 2.7160, Accuracy: 0.3281
# Batch no: 077, Loss on trainig: 2.4873, Accuracy: 0.3906
# Batch no: 078, Loss on trainig: 2.8158, Accuracy: 0.2344
# Batch no: 079, Loss on trainig: 2.5364, Accuracy: 0.3281
# Batch no: 080, Loss on trainig: 2.5405, Accuracy: 0.3438
# Batch no: 081, Loss on trainig: 2.6184, Accuracy: 0.3594
# Batch no: 082, Loss on trainig: 2.2825, Accuracy: 0.3906
# Batch no: 083, Loss on trainig: 2.4745, Accuracy: 0.3906
# Batch no: 084, Loss on trainig: 2.5228, Accuracy: 0.3281
# Batch no: 085, Loss on trainig: 2.3085, Accuracy: 0.4062
# Batch no: 086, Loss on trainig: 2.4650, Accuracy: 0.3750
# Batch no: 087, Loss on trainig: 2.6251, Accuracy: 0.2656
# Batch no: 088, Loss on trainig: 2.4122, Accuracy: 0.3125
# Batch no: 089, Loss on trainig: 2.4765, Accuracy: 0.3125
# Batch no: 090, Loss on trainig: 2.6661, Accuracy: 0.3750
# Batch no: 091, Loss on trainig: 2.4312, Accuracy: 0.3594
# Batch no: 092, Loss on trainig: 2.4829, Accuracy: 0.4062
# Batch no: 093, Loss on trainig: 2.4256, Accuracy: 0.3281
# Batch no: 094, Loss on trainig: 2.7439, Accuracy: 0.3125
# Batch no: 095, Loss on trainig: 2.3810, Accuracy: 0.3906
# Batch no: 096, Loss on trainig: 2.3740, Accuracy: 0.3594
# Batch no: 097, Loss on trainig: 2.2591, Accuracy: 0.3438
# Batch no: 098, Loss on trainig: 2.2801, Accuracy: 0.3438
# Batch no: 099, Loss on trainig: 2.3966, Accuracy: 0.3906
# Batch no: 100, Loss on trainig: 2.5514, Accuracy: 0.2969
# Batch no: 101, Loss on trainig: 2.3090, Accuracy: 0.3906
# Batch no: 102, Loss on trainig: 2.7941, Accuracy: 0.2500
# Epoch: 3/18
# Batch no: 000, Loss on trainig: 2.1950, Accuracy: 0.4219
# Batch no: 001, Loss on trainig: 2.4360, Accuracy: 0.3906
# Batch no: 002, Loss on trainig: 2.1166, Accuracy: 0.4531
# Batch no: 003, Loss on trainig: 2.3074, Accuracy: 0.3125
# Batch no: 004, Loss on trainig: 2.0356, Accuracy: 0.4844
# Batch no: 005, Loss on trainig: 2.1305, Accuracy: 0.4531
# Batch no: 006, Loss on trainig: 2.5452, Accuracy: 0.4062
# Batch no: 007, Loss on trainig: 2.2105, Accuracy: 0.4219
# Batch no: 008, Loss on trainig: 2.1783, Accuracy: 0.4375
# Batch no: 009, Loss on trainig: 2.1998, Accuracy: 0.4219
# Batch no: 010, Loss on trainig: 2.3311, Accuracy: 0.3750
# Batch no: 011, Loss on trainig: 2.0879, Accuracy: 0.4531
# Batch no: 012, Loss on trainig: 2.7428, Accuracy: 0.2969
# Batch no: 013, Loss on trainig: 2.9058, Accuracy: 0.2031
# Batch no: 014, Loss on trainig: 2.3286, Accuracy: 0.3594
# Batch no: 015, Loss on trainig: 2.2999, Accuracy: 0.3438
# Batch no: 016, Loss on trainig: 2.5684, Accuracy: 0.2969
# Batch no: 017, Loss on trainig: 2.4718, Accuracy: 0.3594
# Batch no: 018, Loss on trainig: 2.3229, Accuracy: 0.3906
# Batch no: 019, Loss on trainig: 2.5611, Accuracy: 0.3281
# Batch no: 020, Loss on trainig: 2.2994, Accuracy: 0.3438
# Batch no: 021, Loss on trainig: 2.1144, Accuracy: 0.4219
# Batch no: 022, Loss on trainig: 2.3845, Accuracy: 0.3594
# Batch no: 023, Loss on trainig: 2.2876, Accuracy: 0.3594
# Batch no: 024, Loss on trainig: 2.7929, Accuracy: 0.2656
# Batch no: 025, Loss on trainig: 2.2994, Accuracy: 0.4219
# Batch no: 026, Loss on trainig: 2.2566, Accuracy: 0.4219
# Batch no: 027, Loss on trainig: 2.4357, Accuracy: 0.3281
# Batch no: 028, Loss on trainig: 1.6531, Accuracy: 0.5938
# Batch no: 029, Loss on trainig: 2.3572, Accuracy: 0.3750
# Batch no: 030, Loss on trainig: 2.3596, Accuracy: 0.3906
# Batch no: 031, Loss on trainig: 2.7594, Accuracy: 0.3594
# Batch no: 032, Loss on trainig: 2.0667, Accuracy: 0.4219
# Batch no: 033, Loss on trainig: 2.7109, Accuracy: 0.2969
# Batch no: 034, Loss on trainig: 2.4132, Accuracy: 0.3125
# Batch no: 035, Loss on trainig: 2.1722, Accuracy: 0.4219
# Batch no: 036, Loss on trainig: 1.9690, Accuracy: 0.5469
# Batch no: 037, Loss on trainig: 2.3039, Accuracy: 0.4688
# Batch no: 038, Loss on trainig: 2.1039, Accuracy: 0.4375
# Batch no: 039, Loss on trainig: 2.1003, Accuracy: 0.3906
# Batch no: 040, Loss on trainig: 2.0097, Accuracy: 0.4531
# Batch no: 041, Loss on trainig: 2.1143, Accuracy: 0.4062
# Batch no: 042, Loss on trainig: 1.9167, Accuracy: 0.4375
# Batch no: 043, Loss on trainig: 2.3976, Accuracy: 0.3750
# Batch no: 044, Loss on trainig: 2.1269, Accuracy: 0.3750
# Batch no: 045, Loss on trainig: 2.3512, Accuracy: 0.4375
# Batch no: 046, Loss on trainig: 2.3219, Accuracy: 0.3906
# Batch no: 047, Loss on trainig: 1.8225, Accuracy: 0.4844
# Batch no: 048, Loss on trainig: 2.2484, Accuracy: 0.4531
# Batch no: 049, Loss on trainig: 1.9557, Accuracy: 0.4375
# Batch no: 050, Loss on trainig: 2.1374, Accuracy: 0.4219
# Batch no: 051, Loss on trainig: 2.1789, Accuracy: 0.4375
# Batch no: 052, Loss on trainig: 2.3953, Accuracy: 0.3594
# Batch no: 053, Loss on trainig: 1.9476, Accuracy: 0.4844
# Batch no: 054, Loss on trainig: 2.2341, Accuracy: 0.3750
# Batch no: 055, Loss on trainig: 2.6795, Accuracy: 0.3281
# Batch no: 056, Loss on trainig: 2.1566, Accuracy: 0.4375
# Batch no: 057, Loss on trainig: 2.1568, Accuracy: 0.3438
# Batch no: 058, Loss on trainig: 2.7053, Accuracy: 0.2812
# Batch no: 059, Loss on trainig: 1.6382, Accuracy: 0.5156
# Batch no: 060, Loss on trainig: 2.5302, Accuracy: 0.3281
# Batch no: 061, Loss on trainig: 2.1553, Accuracy: 0.3906
# Batch no: 062, Loss on trainig: 2.1943, Accuracy: 0.4062
# Batch no: 063, Loss on trainig: 2.3748, Accuracy: 0.2500
# Batch no: 064, Loss on trainig: 2.3948, Accuracy: 0.3594
# Batch no: 065, Loss on trainig: 2.2763, Accuracy: 0.4375
# Batch no: 066, Loss on trainig: 2.1199, Accuracy: 0.4062
# Batch no: 067, Loss on trainig: 2.1834, Accuracy: 0.4062
# Batch no: 068, Loss on trainig: 2.7464, Accuracy: 0.3125
# Batch no: 069, Loss on trainig: 2.0535, Accuracy: 0.4062
# Batch no: 070, Loss on trainig: 2.1623, Accuracy: 0.4688
# Batch no: 071, Loss on trainig: 2.2276, Accuracy: 0.3906
# Batch no: 072, Loss on trainig: 2.1103, Accuracy: 0.4375
# Batch no: 073, Loss on trainig: 2.4662, Accuracy: 0.3750
# Batch no: 074, Loss on trainig: 1.9473, Accuracy: 0.5312
# Batch no: 075, Loss on trainig: 1.9717, Accuracy: 0.4844
# Batch no: 076, Loss on trainig: 2.3299, Accuracy: 0.4375
# Batch no: 077, Loss on trainig: 2.3037, Accuracy: 0.4062
# Batch no: 078, Loss on trainig: 2.0877, Accuracy: 0.4219
# Batch no: 079, Loss on trainig: 1.9154, Accuracy: 0.5156
# Batch no: 080, Loss on trainig: 1.9437, Accuracy: 0.4375
# Batch no: 081, Loss on trainig: 2.0731, Accuracy: 0.4062
# Batch no: 082, Loss on trainig: 2.3503, Accuracy: 0.4062
# Batch no: 083, Loss on trainig: 2.2541, Accuracy: 0.4062
# Batch no: 084, Loss on trainig: 2.3420, Accuracy: 0.3750
# Batch no: 085, Loss on trainig: 2.3678, Accuracy: 0.3438
# Batch no: 086, Loss on trainig: 2.1691, Accuracy: 0.4688
# Batch no: 087, Loss on trainig: 2.2123, Accuracy: 0.3906
# Batch no: 088, Loss on trainig: 2.4939, Accuracy: 0.3594
# Batch no: 089, Loss on trainig: 1.8335, Accuracy: 0.4375
# Batch no: 090, Loss on trainig: 2.0211, Accuracy: 0.5000
# Batch no: 091, Loss on trainig: 2.3878, Accuracy: 0.3750
# Batch no: 092, Loss on trainig: 2.2887, Accuracy: 0.3750
# Batch no: 093, Loss on trainig: 1.9651, Accuracy: 0.4375
# Batch no: 094, Loss on trainig: 1.9814, Accuracy: 0.4219
# Batch no: 095, Loss on trainig: 2.1378, Accuracy: 0.5000
# Batch no: 096, Loss on trainig: 2.3722, Accuracy: 0.3125
# Batch no: 097, Loss on trainig: 2.0443, Accuracy: 0.4688
# Batch no: 098, Loss on trainig: 1.9954, Accuracy: 0.4375
# Batch no: 099, Loss on trainig: 2.3030, Accuracy: 0.2969
# Batch no: 100, Loss on trainig: 2.3042, Accuracy: 0.4219
# Batch no: 101, Loss on trainig: 2.1668, Accuracy: 0.3750
# Batch no: 102, Loss on trainig: 2.3890, Accuracy: 0.4167
# Epoch: 4/18
# Batch no: 000, Loss on trainig: 1.8900, Accuracy: 0.4375
# Batch no: 001, Loss on trainig: 2.3011, Accuracy: 0.3594
# Batch no: 002, Loss on trainig: 2.3068, Accuracy: 0.4219
# Batch no: 003, Loss on trainig: 2.1482, Accuracy: 0.4062
# Batch no: 004, Loss on trainig: 2.1193, Accuracy: 0.4844
# Batch no: 005, Loss on trainig: 2.0158, Accuracy: 0.5000
# Batch no: 006, Loss on trainig: 2.2105, Accuracy: 0.4219
# Batch no: 007, Loss on trainig: 2.5652, Accuracy: 0.3281
# Batch no: 008, Loss on trainig: 2.3523, Accuracy: 0.4062
# Batch no: 009, Loss on trainig: 2.0999, Accuracy: 0.4688
# Batch no: 010, Loss on trainig: 1.9902, Accuracy: 0.4688
# Batch no: 011, Loss on trainig: 2.1482, Accuracy: 0.3906
# Batch no: 012, Loss on trainig: 2.0766, Accuracy: 0.5000
# Batch no: 013, Loss on trainig: 2.1417, Accuracy: 0.4062
# Batch no: 014, Loss on trainig: 2.3164, Accuracy: 0.4531
# Batch no: 015, Loss on trainig: 1.8418, Accuracy: 0.4844
# Batch no: 016, Loss on trainig: 1.8100, Accuracy: 0.5156
# Batch no: 017, Loss on trainig: 2.0491, Accuracy: 0.4375
# Batch no: 018, Loss on trainig: 2.0218, Accuracy: 0.5000
# Batch no: 019, Loss on trainig: 2.0323, Accuracy: 0.3750
# Batch no: 020, Loss on trainig: 2.2090, Accuracy: 0.4219
# Batch no: 021, Loss on trainig: 1.9786, Accuracy: 0.4844
# Batch no: 022, Loss on trainig: 2.3165, Accuracy: 0.4375
# Batch no: 023, Loss on trainig: 2.1060, Accuracy: 0.4062
# Batch no: 024, Loss on trainig: 2.3490, Accuracy: 0.3750
# Batch no: 025, Loss on trainig: 1.9041, Accuracy: 0.5312
# Batch no: 026, Loss on trainig: 2.1922, Accuracy: 0.3281
# Batch no: 027, Loss on trainig: 2.2245, Accuracy: 0.4688
# Batch no: 028, Loss on trainig: 1.9978, Accuracy: 0.4531
# Batch no: 029, Loss on trainig: 2.4152, Accuracy: 0.3594
# Batch no: 030, Loss on trainig: 1.9809, Accuracy: 0.4062
# Batch no: 031, Loss on trainig: 2.1567, Accuracy: 0.4688
# Batch no: 032, Loss on trainig: 2.1032, Accuracy: 0.4375
# Batch no: 033, Loss on trainig: 2.2805, Accuracy: 0.3594
# Batch no: 034, Loss on trainig: 1.6939, Accuracy: 0.5156
# Batch no: 035, Loss on trainig: 1.9063, Accuracy: 0.5156
# Batch no: 036, Loss on trainig: 1.8876, Accuracy: 0.4219
# Batch no: 037, Loss on trainig: 1.9513, Accuracy: 0.4531
# Batch no: 038, Loss on trainig: 1.9244, Accuracy: 0.4531
# Batch no: 039, Loss on trainig: 2.0616, Accuracy: 0.4844
# Batch no: 040, Loss on trainig: 2.1769, Accuracy: 0.4219
# Batch no: 041, Loss on trainig: 2.1156, Accuracy: 0.3906
# Batch no: 042, Loss on trainig: 1.7658, Accuracy: 0.5000
# Batch no: 043, Loss on trainig: 2.0832, Accuracy: 0.4375
# Batch no: 044, Loss on trainig: 1.8542, Accuracy: 0.5156
# Batch no: 045, Loss on trainig: 1.8014, Accuracy: 0.4688
# Batch no: 046, Loss on trainig: 2.2323, Accuracy: 0.3438
# Batch no: 047, Loss on trainig: 1.8813, Accuracy: 0.4531
# Batch no: 048, Loss on trainig: 2.1420, Accuracy: 0.4531
# Batch no: 049, Loss on trainig: 1.9572, Accuracy: 0.4062
# Batch no: 050, Loss on trainig: 1.7560, Accuracy: 0.5625
# Batch no: 051, Loss on trainig: 2.2258, Accuracy: 0.4219
# Batch no: 052, Loss on trainig: 1.9801, Accuracy: 0.4219
# Batch no: 053, Loss on trainig: 1.9134, Accuracy: 0.4062
# Batch no: 054, Loss on trainig: 1.9599, Accuracy: 0.4375
# Batch no: 055, Loss on trainig: 1.7667, Accuracy: 0.5312
# Batch no: 056, Loss on trainig: 1.9203, Accuracy: 0.4844
# Batch no: 057, Loss on trainig: 2.3083, Accuracy: 0.4219
# Batch no: 058, Loss on trainig: 2.3882, Accuracy: 0.3906
# Batch no: 059, Loss on trainig: 1.8691, Accuracy: 0.4844
# Batch no: 060, Loss on trainig: 2.1732, Accuracy: 0.4531
# Batch no: 061, Loss on trainig: 1.6118, Accuracy: 0.5000
# Batch no: 062, Loss on trainig: 2.1487, Accuracy: 0.3906
# Batch no: 063, Loss on trainig: 2.1702, Accuracy: 0.4219
# Batch no: 064, Loss on trainig: 1.8222, Accuracy: 0.4688
# Batch no: 065, Loss on trainig: 2.2932, Accuracy: 0.3438
# Batch no: 066, Loss on trainig: 2.4646, Accuracy: 0.3594
# Batch no: 067, Loss on trainig: 1.9154, Accuracy: 0.5000
# Batch no: 068, Loss on trainig: 1.9563, Accuracy: 0.4219
# Batch no: 069, Loss on trainig: 1.5508, Accuracy: 0.4844
# Batch no: 070, Loss on trainig: 1.8281, Accuracy: 0.4531
# Batch no: 071, Loss on trainig: 2.0071, Accuracy: 0.3438
# Batch no: 072, Loss on trainig: 1.5963, Accuracy: 0.5938
# Batch no: 073, Loss on trainig: 1.9300, Accuracy: 0.4531
# Batch no: 074, Loss on trainig: 2.1679, Accuracy: 0.3906
# Batch no: 075, Loss on trainig: 1.3461, Accuracy: 0.6562
# Batch no: 076, Loss on trainig: 1.8871, Accuracy: 0.4531
# Batch no: 077, Loss on trainig: 2.1391, Accuracy: 0.3438
# Batch no: 078, Loss on trainig: 1.7728, Accuracy: 0.5312
# Batch no: 079, Loss on trainig: 1.9138, Accuracy: 0.5469
# Batch no: 080, Loss on trainig: 1.9099, Accuracy: 0.5312
# Batch no: 081, Loss on trainig: 2.1766, Accuracy: 0.4688
# Batch no: 082, Loss on trainig: 2.1272, Accuracy: 0.4531
# Batch no: 083, Loss on trainig: 1.9716, Accuracy: 0.4375
# Batch no: 084, Loss on trainig: 1.6635, Accuracy: 0.5469
# Batch no: 085, Loss on trainig: 1.6867, Accuracy: 0.5469
# Batch no: 086, Loss on trainig: 2.3971, Accuracy: 0.3594
# Batch no: 087, Loss on trainig: 1.9878, Accuracy: 0.5156
# Batch no: 088, Loss on trainig: 2.0389, Accuracy: 0.5312
# Batch no: 089, Loss on trainig: 1.8882, Accuracy: 0.5156
# Batch no: 090, Loss on trainig: 1.8491, Accuracy: 0.4375
# Batch no: 091, Loss on trainig: 1.4691, Accuracy: 0.5781
# Batch no: 092, Loss on trainig: 1.8782, Accuracy: 0.5000
# Batch no: 093, Loss on trainig: 1.8422, Accuracy: 0.5469
# Batch no: 094, Loss on trainig: 2.1891, Accuracy: 0.3906
# Batch no: 095, Loss on trainig: 1.8543, Accuracy: 0.4219
# Batch no: 096, Loss on trainig: 2.1586, Accuracy: 0.4062
# Batch no: 097, Loss on trainig: 2.1688, Accuracy: 0.4375
# Batch no: 098, Loss on trainig: 1.6648, Accuracy: 0.5156
# Batch no: 099, Loss on trainig: 1.5590, Accuracy: 0.5781
# Batch no: 100, Loss on trainig: 2.1385, Accuracy: 0.4531
# Batch no: 101, Loss on trainig: 1.7958, Accuracy: 0.5312
# Batch no: 102, Loss on trainig: 2.3910, Accuracy: 0.3333
# Epoch: 5/18
# Batch no: 000, Loss on trainig: 1.7822, Accuracy: 0.4531
# Batch no: 001, Loss on trainig: 1.9499, Accuracy: 0.5156
# Batch no: 002, Loss on trainig: 1.7280, Accuracy: 0.5000
# Batch no: 003, Loss on trainig: 1.9860, Accuracy: 0.4531
# Batch no: 004, Loss on trainig: 1.7065, Accuracy: 0.5312
# Batch no: 005, Loss on trainig: 2.0687, Accuracy: 0.5312
# Batch no: 006, Loss on trainig: 1.9026, Accuracy: 0.5625
# Batch no: 007, Loss on trainig: 2.3757, Accuracy: 0.3594
# Batch no: 008, Loss on trainig: 1.8144, Accuracy: 0.5000
# Batch no: 009, Loss on trainig: 2.3079, Accuracy: 0.3906
# Batch no: 010, Loss on trainig: 1.7664, Accuracy: 0.5469
# Batch no: 011, Loss on trainig: 1.9190, Accuracy: 0.4844
# Batch no: 012, Loss on trainig: 2.1283, Accuracy: 0.4219
# Batch no: 013, Loss on trainig: 1.7626, Accuracy: 0.5000
# Batch no: 014, Loss on trainig: 1.8707, Accuracy: 0.5000
# Batch no: 015, Loss on trainig: 1.9274, Accuracy: 0.3906
# Batch no: 016, Loss on trainig: 1.8853, Accuracy: 0.4375
# Batch no: 017, Loss on trainig: 1.5038, Accuracy: 0.5938
# Batch no: 018, Loss on trainig: 1.8388, Accuracy: 0.5000
# Batch no: 019, Loss on trainig: 1.6872, Accuracy: 0.5781
# Batch no: 020, Loss on trainig: 1.8822, Accuracy: 0.4844
# Batch no: 021, Loss on trainig: 2.0290, Accuracy: 0.4531
# Batch no: 022, Loss on trainig: 2.1139, Accuracy: 0.4688
# Batch no: 023, Loss on trainig: 1.9462, Accuracy: 0.4844
# Batch no: 024, Loss on trainig: 2.2382, Accuracy: 0.4062
# Batch no: 025, Loss on trainig: 2.0235, Accuracy: 0.4844
# Batch no: 026, Loss on trainig: 1.6864, Accuracy: 0.4688
# Batch no: 027, Loss on trainig: 1.9810, Accuracy: 0.4062
# Batch no: 028, Loss on trainig: 1.7705, Accuracy: 0.5156
# Batch no: 029, Loss on trainig: 1.9393, Accuracy: 0.4375
# Batch no: 030, Loss on trainig: 1.6713, Accuracy: 0.5312
# Batch no: 031, Loss on trainig: 1.6564, Accuracy: 0.5156
# Batch no: 032, Loss on trainig: 1.7078, Accuracy: 0.5469
# Batch no: 033, Loss on trainig: 1.7368, Accuracy: 0.5469
# Batch no: 034, Loss on trainig: 1.8752, Accuracy: 0.4688
# Batch no: 035, Loss on trainig: 1.7654, Accuracy: 0.4531
# Batch no: 036, Loss on trainig: 1.7725, Accuracy: 0.4688
# Batch no: 037, Loss on trainig: 1.6688, Accuracy: 0.5469
# Batch no: 038, Loss on trainig: 1.5562, Accuracy: 0.5469
# Batch no: 039, Loss on trainig: 2.0178, Accuracy: 0.3906
# Batch no: 040, Loss on trainig: 1.5746, Accuracy: 0.4844
# Batch no: 041, Loss on trainig: 1.6631, Accuracy: 0.5781
# Batch no: 042, Loss on trainig: 1.6302, Accuracy: 0.5938
# Batch no: 043, Loss on trainig: 1.9385, Accuracy: 0.4375
# Batch no: 044, Loss on trainig: 1.9755, Accuracy: 0.4844
# Batch no: 045, Loss on trainig: 1.4142, Accuracy: 0.5625
# Batch no: 046, Loss on trainig: 1.8159, Accuracy: 0.4375
# Batch no: 047, Loss on trainig: 2.0260, Accuracy: 0.4375
# Batch no: 048, Loss on trainig: 1.6864, Accuracy: 0.4688
# Batch no: 049, Loss on trainig: 1.5185, Accuracy: 0.6250
# Batch no: 050, Loss on trainig: 1.9537, Accuracy: 0.4219
# Batch no: 051, Loss on trainig: 1.7786, Accuracy: 0.4688
# Batch no: 052, Loss on trainig: 1.7824, Accuracy: 0.5156
# Batch no: 053, Loss on trainig: 1.7055, Accuracy: 0.5781
# Batch no: 054, Loss on trainig: 1.6878, Accuracy: 0.5000
# Batch no: 055, Loss on trainig: 1.7662, Accuracy: 0.4844
# Batch no: 056, Loss on trainig: 1.9306, Accuracy: 0.5156
# Batch no: 057, Loss on trainig: 1.8716, Accuracy: 0.4531
# Batch no: 058, Loss on trainig: 1.7718, Accuracy: 0.5312
# Batch no: 059, Loss on trainig: 1.9387, Accuracy: 0.5156
# Batch no: 060, Loss on trainig: 2.1326, Accuracy: 0.4062
# Batch no: 061, Loss on trainig: 1.8305, Accuracy: 0.4531
# Batch no: 062, Loss on trainig: 1.8664, Accuracy: 0.4375
# Batch no: 063, Loss on trainig: 1.9679, Accuracy: 0.4531
# Batch no: 064, Loss on trainig: 1.8404, Accuracy: 0.4531
# Batch no: 065, Loss on trainig: 2.0735, Accuracy: 0.5000
# Batch no: 066, Loss on trainig: 1.6925, Accuracy: 0.5000
# Batch no: 067, Loss on trainig: 1.9216, Accuracy: 0.4375
# Batch no: 068, Loss on trainig: 2.1623, Accuracy: 0.3906
# Batch no: 069, Loss on trainig: 1.9719, Accuracy: 0.4219
# Batch no: 070, Loss on trainig: 1.9697, Accuracy: 0.4531
# Batch no: 071, Loss on trainig: 1.8778, Accuracy: 0.4844
# Batch no: 072, Loss on trainig: 1.8360, Accuracy: 0.5312
# Batch no: 073, Loss on trainig: 1.7263, Accuracy: 0.5000
# Batch no: 074, Loss on trainig: 2.0773, Accuracy: 0.5000
# Batch no: 075, Loss on trainig: 2.0466, Accuracy: 0.4531
# Batch no: 076, Loss on trainig: 2.0459, Accuracy: 0.4375
# Batch no: 077, Loss on trainig: 2.3127, Accuracy: 0.4219
# Batch no: 078, Loss on trainig: 2.0715, Accuracy: 0.4688
# Batch no: 079, Loss on trainig: 1.9850, Accuracy: 0.4531
# Batch no: 080, Loss on trainig: 1.8646, Accuracy: 0.5000
# Batch no: 081, Loss on trainig: 2.1532, Accuracy: 0.4688
# Batch no: 082, Loss on trainig: 1.5539, Accuracy: 0.5781
# Batch no: 083, Loss on trainig: 1.8217, Accuracy: 0.5156
# Batch no: 084, Loss on trainig: 1.8295, Accuracy: 0.4375
# Batch no: 085, Loss on trainig: 1.5615, Accuracy: 0.5469
# Batch no: 086, Loss on trainig: 1.6466, Accuracy: 0.6094
# Batch no: 087, Loss on trainig: 1.6617, Accuracy: 0.5781
# Batch no: 088, Loss on trainig: 1.8619, Accuracy: 0.4531
# Batch no: 089, Loss on trainig: 1.9270, Accuracy: 0.4688
# Batch no: 090, Loss on trainig: 1.9791, Accuracy: 0.3750
# Batch no: 091, Loss on trainig: 2.2549, Accuracy: 0.4219
# Batch no: 092, Loss on trainig: 1.8859, Accuracy: 0.5000
# Batch no: 093, Loss on trainig: 2.1483, Accuracy: 0.4844
# Batch no: 094, Loss on trainig: 2.1262, Accuracy: 0.3594
# Batch no: 095, Loss on trainig: 2.0818, Accuracy: 0.5156
# Batch no: 096, Loss on trainig: 1.8390, Accuracy: 0.5156
# Batch no: 097, Loss on trainig: 1.8546, Accuracy: 0.5312
# Batch no: 098, Loss on trainig: 2.0367, Accuracy: 0.4531
# Batch no: 099, Loss on trainig: 1.9475, Accuracy: 0.5000
# Batch no: 100, Loss on trainig: 1.6871, Accuracy: 0.5469
# Batch no: 101, Loss on trainig: 1.5952, Accuracy: 0.5781
# Batch no: 102, Loss on trainig: 0.9699, Accuracy: 0.7083
# Epoch: 6/18
# Batch no: 000, Loss on trainig: 1.5979, Accuracy: 0.5469
# Batch no: 001, Loss on trainig: 1.6412, Accuracy: 0.5781
# Batch no: 002, Loss on trainig: 1.5975, Accuracy: 0.5938
# Batch no: 003, Loss on trainig: 1.8213, Accuracy: 0.4844
# Batch no: 004, Loss on trainig: 2.0176, Accuracy: 0.4688
# Batch no: 005, Loss on trainig: 2.0475, Accuracy: 0.3750
# Batch no: 006, Loss on trainig: 1.6682, Accuracy: 0.5156
# Batch no: 007, Loss on trainig: 1.9235, Accuracy: 0.5000
# Batch no: 008, Loss on trainig: 1.8701, Accuracy: 0.5625
# Batch no: 009, Loss on trainig: 1.7547, Accuracy: 0.5000
# Batch no: 010, Loss on trainig: 1.7905, Accuracy: 0.5625
# Batch no: 011, Loss on trainig: 1.6027, Accuracy: 0.4844
# Batch no: 012, Loss on trainig: 1.7906, Accuracy: 0.5312
# Batch no: 013, Loss on trainig: 1.7795, Accuracy: 0.5469
# Batch no: 014, Loss on trainig: 1.6137, Accuracy: 0.5156
# Batch no: 015, Loss on trainig: 1.9009, Accuracy: 0.4062
# Batch no: 016, Loss on trainig: 1.5424, Accuracy: 0.5156
# Batch no: 017, Loss on trainig: 1.4289, Accuracy: 0.5938
# Batch no: 018, Loss on trainig: 1.5491, Accuracy: 0.4688
# Batch no: 019, Loss on trainig: 2.0985, Accuracy: 0.4219
# Batch no: 020, Loss on trainig: 1.3026, Accuracy: 0.6406
# Batch no: 021, Loss on trainig: 1.7435, Accuracy: 0.4688
# Batch no: 022, Loss on trainig: 1.4865, Accuracy: 0.5312
# Batch no: 023, Loss on trainig: 1.9803, Accuracy: 0.5156
# Batch no: 024, Loss on trainig: 1.9558, Accuracy: 0.4844
# Batch no: 025, Loss on trainig: 2.0178, Accuracy: 0.4844
# Batch no: 026, Loss on trainig: 1.8556, Accuracy: 0.4375
# Batch no: 027, Loss on trainig: 1.8884, Accuracy: 0.5156
# Batch no: 028, Loss on trainig: 1.7105, Accuracy: 0.4844
# Batch no: 029, Loss on trainig: 1.8984, Accuracy: 0.5000
# Batch no: 030, Loss on trainig: 1.6190, Accuracy: 0.5156
# Batch no: 031, Loss on trainig: 1.7406, Accuracy: 0.5312
# Batch no: 032, Loss on trainig: 1.6791, Accuracy: 0.5312
# Batch no: 033, Loss on trainig: 1.8860, Accuracy: 0.5000
# Batch no: 034, Loss on trainig: 1.5191, Accuracy: 0.5156
# Batch no: 035, Loss on trainig: 2.0402, Accuracy: 0.4375
# Batch no: 036, Loss on trainig: 1.7030, Accuracy: 0.4844
# Batch no: 037, Loss on trainig: 1.7579, Accuracy: 0.4375
# Batch no: 038, Loss on trainig: 1.6814, Accuracy: 0.5625
# Batch no: 039, Loss on trainig: 1.4643, Accuracy: 0.6094
# Batch no: 040, Loss on trainig: 1.9360, Accuracy: 0.5312
# Batch no: 041, Loss on trainig: 1.6237, Accuracy: 0.5469
# Batch no: 042, Loss on trainig: 1.5235, Accuracy: 0.5312
# Batch no: 043, Loss on trainig: 1.5503, Accuracy: 0.6250
# Batch no: 044, Loss on trainig: 1.8088, Accuracy: 0.4844
# Batch no: 045, Loss on trainig: 1.8136, Accuracy: 0.5000
# Batch no: 046, Loss on trainig: 1.6714, Accuracy: 0.4531
# Batch no: 047, Loss on trainig: 1.8379, Accuracy: 0.4375
# Batch no: 048, Loss on trainig: 1.8538, Accuracy: 0.5000
# Batch no: 049, Loss on trainig: 1.6912, Accuracy: 0.5781
# Batch no: 050, Loss on trainig: 1.7789, Accuracy: 0.4844
# Batch no: 051, Loss on trainig: 2.0563, Accuracy: 0.5000
# Batch no: 052, Loss on trainig: 1.8032, Accuracy: 0.5469
# Batch no: 053, Loss on trainig: 1.7890, Accuracy: 0.5156
# Batch no: 054, Loss on trainig: 1.7177, Accuracy: 0.5156
# Batch no: 055, Loss on trainig: 1.6086, Accuracy: 0.5469
# Batch no: 056, Loss on trainig: 2.1372, Accuracy: 0.4531
# Batch no: 057, Loss on trainig: 2.0680, Accuracy: 0.5000
# Batch no: 058, Loss on trainig: 1.9972, Accuracy: 0.5000
# Batch no: 059, Loss on trainig: 1.5479, Accuracy: 0.5625
# Batch no: 060, Loss on trainig: 1.7156, Accuracy: 0.5781
# Batch no: 061, Loss on trainig: 1.6937, Accuracy: 0.5312
# Batch no: 062, Loss on trainig: 1.9434, Accuracy: 0.4062
# Batch no: 063, Loss on trainig: 1.8354, Accuracy: 0.5781
# Batch no: 064, Loss on trainig: 2.1094, Accuracy: 0.3594
# Batch no: 065, Loss on trainig: 1.7402, Accuracy: 0.5469
# Batch no: 066, Loss on trainig: 1.5125, Accuracy: 0.5625
# Batch no: 067, Loss on trainig: 1.7865, Accuracy: 0.5625
# Batch no: 068, Loss on trainig: 1.7498, Accuracy: 0.5156
# Batch no: 069, Loss on trainig: 1.7765, Accuracy: 0.4844
# Batch no: 070, Loss on trainig: 2.4513, Accuracy: 0.3750
# Batch no: 071, Loss on trainig: 1.7371, Accuracy: 0.6094
# Batch no: 072, Loss on trainig: 2.0425, Accuracy: 0.5156
# Batch no: 073, Loss on trainig: 1.9783, Accuracy: 0.4844
# Batch no: 074, Loss on trainig: 2.1444, Accuracy: 0.5156
# Batch no: 075, Loss on trainig: 1.6984, Accuracy: 0.5156
# Batch no: 076, Loss on trainig: 1.7192, Accuracy: 0.4844
# Batch no: 077, Loss on trainig: 1.6497, Accuracy: 0.5000
# Batch no: 078, Loss on trainig: 1.8063, Accuracy: 0.5000
# Batch no: 079, Loss on trainig: 1.9583, Accuracy: 0.4844
# Batch no: 080, Loss on trainig: 1.4659, Accuracy: 0.5781
# Batch no: 081, Loss on trainig: 1.6171, Accuracy: 0.5312
# Batch no: 082, Loss on trainig: 1.5738, Accuracy: 0.4688
# Batch no: 083, Loss on trainig: 1.6415, Accuracy: 0.4844
# Batch no: 084, Loss on trainig: 1.7240, Accuracy: 0.4688
# Batch no: 085, Loss on trainig: 1.7916, Accuracy: 0.5000
# Batch no: 086, Loss on trainig: 1.5831, Accuracy: 0.5156
# Batch no: 087, Loss on trainig: 1.5943, Accuracy: 0.5625
# Batch no: 088, Loss on trainig: 1.6254, Accuracy: 0.6250
# Batch no: 089, Loss on trainig: 1.9988, Accuracy: 0.4219
# Batch no: 090, Loss on trainig: 1.8292, Accuracy: 0.4844
# Batch no: 091, Loss on trainig: 1.8491, Accuracy: 0.5469
# Batch no: 092, Loss on trainig: 1.9564, Accuracy: 0.4844
# Batch no: 093, Loss on trainig: 1.5206, Accuracy: 0.5469
# Batch no: 094, Loss on trainig: 1.8537, Accuracy: 0.4844
# Batch no: 095, Loss on trainig: 1.5361, Accuracy: 0.5469
# Batch no: 096, Loss on trainig: 1.6794, Accuracy: 0.4844
# Batch no: 097, Loss on trainig: 1.7879, Accuracy: 0.5312
# Batch no: 098, Loss on trainig: 2.1749, Accuracy: 0.4062
# Batch no: 099, Loss on trainig: 1.9931, Accuracy: 0.4688
# Batch no: 100, Loss on trainig: 1.4489, Accuracy: 0.5781
# Batch no: 101, Loss on trainig: 1.6153, Accuracy: 0.5469
# Batch no: 102, Loss on trainig: 1.9249, Accuracy: 0.4167
# Epoch: 7/18
# Batch no: 000, Loss on trainig: 1.4178, Accuracy: 0.5469
# Batch no: 001, Loss on trainig: 1.7653, Accuracy: 0.5781
# Batch no: 002, Loss on trainig: 1.6558, Accuracy: 0.5469
# Batch no: 003, Loss on trainig: 1.4166, Accuracy: 0.5469
# Batch no: 004, Loss on trainig: 1.2790, Accuracy: 0.6406
# Batch no: 005, Loss on trainig: 2.2057, Accuracy: 0.4219
# Batch no: 006, Loss on trainig: 1.7269, Accuracy: 0.5625
# Batch no: 007, Loss on trainig: 1.6599, Accuracy: 0.5312
# Batch no: 008, Loss on trainig: 1.8995, Accuracy: 0.4375
# Batch no: 009, Loss on trainig: 1.7726, Accuracy: 0.5469
# Batch no: 010, Loss on trainig: 1.6631, Accuracy: 0.4844
# Batch no: 011, Loss on trainig: 1.9087, Accuracy: 0.3750
# Batch no: 012, Loss on trainig: 1.6943, Accuracy: 0.4844
# Batch no: 013, Loss on trainig: 1.6540, Accuracy: 0.5000
# Batch no: 014, Loss on trainig: 1.6725, Accuracy: 0.4688
# Batch no: 015, Loss on trainig: 2.0301, Accuracy: 0.5156
# Batch no: 016, Loss on trainig: 1.5672, Accuracy: 0.5938
# Batch no: 017, Loss on trainig: 1.7369, Accuracy: 0.5156
# Batch no: 018, Loss on trainig: 1.6336, Accuracy: 0.5312
# Batch no: 019, Loss on trainig: 1.8790, Accuracy: 0.5156
# Batch no: 020, Loss on trainig: 1.4199, Accuracy: 0.5938
# Batch no: 021, Loss on trainig: 1.6492, Accuracy: 0.4688
# Batch no: 022, Loss on trainig: 1.2980, Accuracy: 0.7031
# Batch no: 023, Loss on trainig: 1.9102, Accuracy: 0.4844
# Batch no: 024, Loss on trainig: 1.4544, Accuracy: 0.5312
# Batch no: 025, Loss on trainig: 1.7879, Accuracy: 0.5000
# Batch no: 026, Loss on trainig: 1.7304, Accuracy: 0.6562
# Batch no: 027, Loss on trainig: 1.8138, Accuracy: 0.4531
# Batch no: 028, Loss on trainig: 2.1040, Accuracy: 0.4375
# Batch no: 029, Loss on trainig: 1.6408, Accuracy: 0.5781
# Batch no: 030, Loss on trainig: 1.7067, Accuracy: 0.5156
# Batch no: 031, Loss on trainig: 1.4568, Accuracy: 0.6094
# Batch no: 032, Loss on trainig: 1.8089, Accuracy: 0.5156
# Batch no: 033, Loss on trainig: 1.4431, Accuracy: 0.5625
# Batch no: 034, Loss on trainig: 1.7014, Accuracy: 0.5000
# Batch no: 035, Loss on trainig: 1.8455, Accuracy: 0.4219
# Batch no: 036, Loss on trainig: 1.6357, Accuracy: 0.5625
# Batch no: 037, Loss on trainig: 1.9488, Accuracy: 0.4688
# Batch no: 038, Loss on trainig: 1.4215, Accuracy: 0.6094
# Batch no: 039, Loss on trainig: 1.6210, Accuracy: 0.5938
# Batch no: 040, Loss on trainig: 1.5082, Accuracy: 0.6406
# Batch no: 041, Loss on trainig: 1.8863, Accuracy: 0.5000
# Batch no: 042, Loss on trainig: 1.6225, Accuracy: 0.5625
# Batch no: 043, Loss on trainig: 1.8461, Accuracy: 0.5156
# Batch no: 044, Loss on trainig: 1.9412, Accuracy: 0.4531
# Batch no: 045, Loss on trainig: 1.7463, Accuracy: 0.5312
# Batch no: 046, Loss on trainig: 2.3101, Accuracy: 0.3125
# Batch no: 047, Loss on trainig: 1.4434, Accuracy: 0.5312
# Batch no: 048, Loss on trainig: 1.7940, Accuracy: 0.5625
# Batch no: 049, Loss on trainig: 1.6565, Accuracy: 0.5625
# Batch no: 050, Loss on trainig: 1.8453, Accuracy: 0.4375
# Batch no: 051, Loss on trainig: 1.5948, Accuracy: 0.5938
# Batch no: 052, Loss on trainig: 1.5940, Accuracy: 0.5781
# Batch no: 053, Loss on trainig: 1.9895, Accuracy: 0.4531
# Batch no: 054, Loss on trainig: 1.7279, Accuracy: 0.5156
# Batch no: 055, Loss on trainig: 1.7394, Accuracy: 0.5312
# Batch no: 056, Loss on trainig: 1.7831, Accuracy: 0.4844
# Batch no: 057, Loss on trainig: 1.9473, Accuracy: 0.4375
# Batch no: 058, Loss on trainig: 1.5796, Accuracy: 0.6250
# Batch no: 059, Loss on trainig: 2.0057, Accuracy: 0.5312
# Batch no: 060, Loss on trainig: 1.7909, Accuracy: 0.4219
# Batch no: 061, Loss on trainig: 1.9012, Accuracy: 0.5469
# Batch no: 062, Loss on trainig: 1.5125, Accuracy: 0.5781
# Batch no: 063, Loss on trainig: 1.7891, Accuracy: 0.5000
# Batch no: 064, Loss on trainig: 1.4555, Accuracy: 0.5469
# Batch no: 065, Loss on trainig: 1.4914, Accuracy: 0.5938
# Batch no: 066, Loss on trainig: 1.6392, Accuracy: 0.5312
# Batch no: 067, Loss on trainig: 2.1544, Accuracy: 0.4531
# Batch no: 068, Loss on trainig: 1.7109, Accuracy: 0.4844
# Batch no: 069, Loss on trainig: 2.1146, Accuracy: 0.4375
# Batch no: 070, Loss on trainig: 1.7316, Accuracy: 0.6250
# Batch no: 071, Loss on trainig: 1.7343, Accuracy: 0.5000
# Batch no: 072, Loss on trainig: 1.8347, Accuracy: 0.4688
# Batch no: 073, Loss on trainig: 1.8485, Accuracy: 0.4844
# Batch no: 074, Loss on trainig: 1.5355, Accuracy: 0.5469
# Batch no: 075, Loss on trainig: 1.9847, Accuracy: 0.4844
# Batch no: 076, Loss on trainig: 1.8463, Accuracy: 0.4844
# Batch no: 077, Loss on trainig: 1.8444, Accuracy: 0.4844
# Batch no: 078, Loss on trainig: 1.8533, Accuracy: 0.5312
# Batch no: 079, Loss on trainig: 1.5936, Accuracy: 0.5781
# Batch no: 080, Loss on trainig: 1.6784, Accuracy: 0.5469
# Batch no: 081, Loss on trainig: 2.1654, Accuracy: 0.4531
# Batch no: 082, Loss on trainig: 1.6865, Accuracy: 0.5312
# Batch no: 083, Loss on trainig: 1.7880, Accuracy: 0.5000
# Batch no: 084, Loss on trainig: 1.9022, Accuracy: 0.5000
# Batch no: 085, Loss on trainig: 1.2800, Accuracy: 0.6094
# Batch no: 086, Loss on trainig: 1.7454, Accuracy: 0.4844
# Batch no: 087, Loss on trainig: 1.9258, Accuracy: 0.4219
# Batch no: 088, Loss on trainig: 2.0446, Accuracy: 0.4219
# Batch no: 089, Loss on trainig: 1.6028, Accuracy: 0.5625
# Batch no: 090, Loss on trainig: 1.5009, Accuracy: 0.5625
# Batch no: 091, Loss on trainig: 1.6752, Accuracy: 0.5000
# Batch no: 092, Loss on trainig: 1.9208, Accuracy: 0.4844
# Batch no: 093, Loss on trainig: 1.8421, Accuracy: 0.5000
# Batch no: 094, Loss on trainig: 1.7760, Accuracy: 0.5469
# Batch no: 095, Loss on trainig: 1.8223, Accuracy: 0.5312
# Batch no: 096, Loss on trainig: 1.6978, Accuracy: 0.5156
# Batch no: 097, Loss on trainig: 1.4947, Accuracy: 0.5781
# Batch no: 098, Loss on trainig: 1.3887, Accuracy: 0.5938
# Batch no: 099, Loss on trainig: 1.3318, Accuracy: 0.6406
# Batch no: 100, Loss on trainig: 1.7398, Accuracy: 0.5781
# Batch no: 101, Loss on trainig: 2.0813, Accuracy: 0.4531
# Batch no: 102, Loss on trainig: 1.3024, Accuracy: 0.6250
# Epoch: 8/18
# Batch no: 000, Loss on trainig: 1.9681, Accuracy: 0.4375
# Batch no: 001, Loss on trainig: 1.8806, Accuracy: 0.4844
# Batch no: 002, Loss on trainig: 1.2847, Accuracy: 0.6406
# Batch no: 003, Loss on trainig: 2.0051, Accuracy: 0.4219
# Batch no: 004, Loss on trainig: 1.3320, Accuracy: 0.6719
# Batch no: 005, Loss on trainig: 1.5209, Accuracy: 0.5781
# Batch no: 006, Loss on trainig: 1.5240, Accuracy: 0.5938
# Batch no: 007, Loss on trainig: 1.4874, Accuracy: 0.6094
# Batch no: 008, Loss on trainig: 1.4632, Accuracy: 0.5625
# Batch no: 009, Loss on trainig: 1.5018, Accuracy: 0.5625
# Batch no: 010, Loss on trainig: 1.8617, Accuracy: 0.5312
# Batch no: 011, Loss on trainig: 1.6405, Accuracy: 0.5312
# Batch no: 012, Loss on trainig: 1.6648, Accuracy: 0.4688
# Batch no: 013, Loss on trainig: 1.5140, Accuracy: 0.5312
# Batch no: 014, Loss on trainig: 1.4391, Accuracy: 0.6562
# Batch no: 015, Loss on trainig: 1.6596, Accuracy: 0.5312
# Batch no: 016, Loss on trainig: 1.4204, Accuracy: 0.6406
# Batch no: 017, Loss on trainig: 1.2718, Accuracy: 0.6094
# Batch no: 018, Loss on trainig: 2.0505, Accuracy: 0.4375
# Batch no: 019, Loss on trainig: 1.8230, Accuracy: 0.5156
# Batch no: 020, Loss on trainig: 1.5499, Accuracy: 0.5469
# Batch no: 021, Loss on trainig: 1.3910, Accuracy: 0.5938
# Batch no: 022, Loss on trainig: 1.6787, Accuracy: 0.5469
# Batch no: 023, Loss on trainig: 1.9123, Accuracy: 0.5000
# Batch no: 024, Loss on trainig: 1.5909, Accuracy: 0.5938
# Batch no: 025, Loss on trainig: 1.7953, Accuracy: 0.5000
# Batch no: 026, Loss on trainig: 1.6857, Accuracy: 0.6094
# Batch no: 027, Loss on trainig: 1.7271, Accuracy: 0.4844
# Batch no: 028, Loss on trainig: 1.2430, Accuracy: 0.6562
# Batch no: 029, Loss on trainig: 1.5691, Accuracy: 0.6562
# Batch no: 030, Loss on trainig: 1.8097, Accuracy: 0.5625
# Batch no: 031, Loss on trainig: 1.6372, Accuracy: 0.5625
# Batch no: 032, Loss on trainig: 1.4693, Accuracy: 0.5781
# Batch no: 033, Loss on trainig: 1.4946, Accuracy: 0.5938
# Batch no: 034, Loss on trainig: 1.9888, Accuracy: 0.4375
# Batch no: 035, Loss on trainig: 1.4383, Accuracy: 0.5625
# Batch no: 036, Loss on trainig: 1.7596, Accuracy: 0.4688
# Batch no: 037, Loss on trainig: 1.4791, Accuracy: 0.5781
# Batch no: 038, Loss on trainig: 1.9298, Accuracy: 0.3750
# Batch no: 039, Loss on trainig: 1.7846, Accuracy: 0.5938
# Batch no: 040, Loss on trainig: 1.5962, Accuracy: 0.5469
# Batch no: 041, Loss on trainig: 1.6387, Accuracy: 0.5000
# Batch no: 042, Loss on trainig: 1.3494, Accuracy: 0.6250
# Batch no: 043, Loss on trainig: 1.6482, Accuracy: 0.6250
# Batch no: 044, Loss on trainig: 1.6423, Accuracy: 0.5312
# Batch no: 045, Loss on trainig: 1.4883, Accuracy: 0.5625
# Batch no: 046, Loss on trainig: 1.3282, Accuracy: 0.5625
# Batch no: 047, Loss on trainig: 1.2705, Accuracy: 0.5938
# Batch no: 048, Loss on trainig: 2.1557, Accuracy: 0.5312
# Batch no: 049, Loss on trainig: 1.5723, Accuracy: 0.6094
# Batch no: 050, Loss on trainig: 1.5669, Accuracy: 0.6094
# Batch no: 051, Loss on trainig: 1.7876, Accuracy: 0.5000
# Batch no: 052, Loss on trainig: 1.4416, Accuracy: 0.5938
# Batch no: 053, Loss on trainig: 1.3813, Accuracy: 0.6875
# Batch no: 054, Loss on trainig: 1.3044, Accuracy: 0.6562
# Batch no: 055, Loss on trainig: 2.2229, Accuracy: 0.4219
# Batch no: 056, Loss on trainig: 1.5803, Accuracy: 0.5625
# Batch no: 057, Loss on trainig: 1.8094, Accuracy: 0.4688
# Batch no: 058, Loss on trainig: 1.8930, Accuracy: 0.4844
# Batch no: 059, Loss on trainig: 1.9999, Accuracy: 0.4844
# Batch no: 060, Loss on trainig: 1.1471, Accuracy: 0.5938
# Batch no: 061, Loss on trainig: 1.7538, Accuracy: 0.5469
# Batch no: 062, Loss on trainig: 1.6983, Accuracy: 0.5156
# Batch no: 063, Loss on trainig: 1.4923, Accuracy: 0.6094
# Batch no: 064, Loss on trainig: 1.8749, Accuracy: 0.4375
# Batch no: 065, Loss on trainig: 1.3427, Accuracy: 0.6562
# Batch no: 066, Loss on trainig: 1.2859, Accuracy: 0.6406
# Batch no: 067, Loss on trainig: 1.6356, Accuracy: 0.5938
# Batch no: 068, Loss on trainig: 1.2009, Accuracy: 0.6719
# Batch no: 069, Loss on trainig: 1.9083, Accuracy: 0.4844
# Batch no: 070, Loss on trainig: 1.2839, Accuracy: 0.6562
# Batch no: 071, Loss on trainig: 1.5649, Accuracy: 0.6250
# Batch no: 072, Loss on trainig: 1.6996, Accuracy: 0.5469
# Batch no: 073, Loss on trainig: 1.6962, Accuracy: 0.5625
# Batch no: 074, Loss on trainig: 1.8214, Accuracy: 0.4531
# Batch no: 075, Loss on trainig: 1.7645, Accuracy: 0.5469
# Batch no: 076, Loss on trainig: 1.4467, Accuracy: 0.6250
# Batch no: 077, Loss on trainig: 1.4888, Accuracy: 0.6250
# Batch no: 078, Loss on trainig: 1.5146, Accuracy: 0.5625
# Batch no: 079, Loss on trainig: 2.0318, Accuracy: 0.5000
# Batch no: 080, Loss on trainig: 1.7923, Accuracy: 0.4844
# Batch no: 081, Loss on trainig: 1.3036, Accuracy: 0.5938
# Batch no: 082, Loss on trainig: 1.7020, Accuracy: 0.5312
# Batch no: 083, Loss on trainig: 1.3887, Accuracy: 0.6250
# Batch no: 084, Loss on trainig: 1.7964, Accuracy: 0.4531
# Batch no: 085, Loss on trainig: 1.7619, Accuracy: 0.5469
# Batch no: 086, Loss on trainig: 1.2326, Accuracy: 0.5469
# Batch no: 087, Loss on trainig: 1.7703, Accuracy: 0.5156
# Batch no: 088, Loss on trainig: 1.6115, Accuracy: 0.6250
# Batch no: 089, Loss on trainig: 1.5739, Accuracy: 0.5469
# Batch no: 090, Loss on trainig: 1.5057, Accuracy: 0.6250
# Batch no: 091, Loss on trainig: 1.6352, Accuracy: 0.5781
# Batch no: 092, Loss on trainig: 1.7755, Accuracy: 0.5625
# Batch no: 093, Loss on trainig: 1.9408, Accuracy: 0.4844
# Batch no: 094, Loss on trainig: 1.9784, Accuracy: 0.4375
# Batch no: 095, Loss on trainig: 1.9015, Accuracy: 0.5000
# Batch no: 096, Loss on trainig: 1.4509, Accuracy: 0.5938
# Batch no: 097, Loss on trainig: 1.7474, Accuracy: 0.5469
# Batch no: 098, Loss on trainig: 1.6383, Accuracy: 0.5781
# Batch no: 099, Loss on trainig: 1.5681, Accuracy: 0.5312
# Batch no: 100, Loss on trainig: 1.6107, Accuracy: 0.4844
# Batch no: 101, Loss on trainig: 1.8646, Accuracy: 0.5156
# Batch no: 102, Loss on trainig: 1.5312, Accuracy: 0.5417
# Epoch: 9/18
# Batch no: 000, Loss on trainig: 1.3859, Accuracy: 0.6094
# Batch no: 001, Loss on trainig: 1.3763, Accuracy: 0.5938
# Batch no: 002, Loss on trainig: 1.8341, Accuracy: 0.5312
# Batch no: 003, Loss on trainig: 1.4359, Accuracy: 0.6406
# Batch no: 004, Loss on trainig: 1.6494, Accuracy: 0.5156
# Batch no: 005, Loss on trainig: 1.4641, Accuracy: 0.6250
# Batch no: 006, Loss on trainig: 1.5376, Accuracy: 0.5312
# Batch no: 007, Loss on trainig: 1.8089, Accuracy: 0.5312
# Batch no: 008, Loss on trainig: 1.9128, Accuracy: 0.5156
# Batch no: 009, Loss on trainig: 1.7726, Accuracy: 0.5625
# Batch no: 010, Loss on trainig: 1.7194, Accuracy: 0.5625
# Batch no: 011, Loss on trainig: 1.3490, Accuracy: 0.6094
# Batch no: 012, Loss on trainig: 1.8011, Accuracy: 0.5469
# Batch no: 013, Loss on trainig: 1.9236, Accuracy: 0.5312
# Batch no: 014, Loss on trainig: 1.6224, Accuracy: 0.5469
# Batch no: 015, Loss on trainig: 1.5604, Accuracy: 0.5469
# ...
# Batch no: 029, Loss on trainig: 1.4853, Accuracy: 0.5938
# Batch no: 030, Loss on trainig: 1.3365, Accuracy: 0.6562
# Batch no: 031, Loss on trainig: 1.2622, Accuracy: 0.5938
# Batch no: 032, Loss on trainig: 1.5141, Accuracy: 0.6250
# Batch no: 033, Loss on trainig: 1.2570, Accuracy: 0.5625
# Batch no: 034, Loss on trainig: 1.2269, Accuracy: 0.5938
# Batch no: 035, Loss on trainig: 1.3868, Accuracy: 0.6406
# Batch no: 036, Loss on trainig: 1.0655, Accuracy: 0.6562
# Batch no: 037, Loss on trainig: 1.1540, Accuracy: 0.6406
# Batch no: 038, Loss on trainig: 1.1717, Accuracy: 0.6562
# Batch no: 039, Loss on trainig: 1.2344, Accuracy: 0.6562
# Batch no: 040, Loss on trainig: 1.1948, Accuracy: 0.5938
# Batch no: 041, Loss on trainig: 1.2016, Accuracy: 0.6094
# Batch no: 042, Loss on trainig: 1.1706, Accuracy: 0.6562
# Batch no: 043, Loss on trainig: 1.3826, Accuracy: 0.6719
# Batch no: 044, Loss on trainig: 1.4390, Accuracy: 0.5625
# Batch no: 045, Loss on trainig: 1.3576, Accuracy: 0.6250
# Batch no: 046, Loss on trainig: 1.3768, Accuracy: 0.6250
# Batch no: 047, Loss on trainig: 0.9437, Accuracy: 0.6719
# Batch no: 048, Loss on trainig: 1.4303, Accuracy: 0.6094
# Batch no: 049, Loss on trainig: 1.3178, Accuracy: 0.6250
# Batch no: 050, Loss on trainig: 1.3534, Accuracy: 0.6250
# Batch no: 051, Loss on trainig: 1.0495, Accuracy: 0.7188
# Batch no: 052, Loss on trainig: 1.3253, Accuracy: 0.6406
# Batch no: 053, Loss on trainig: 1.2249, Accuracy: 0.6562
# Batch no: 054, Loss on trainig: 1.5453, Accuracy: 0.6562
# Batch no: 055, Loss on trainig: 1.2840, Accuracy: 0.6406
# Batch no: 056, Loss on trainig: 1.3457, Accuracy: 0.5625
# Batch no: 057, Loss on trainig: 1.4224, Accuracy: 0.6719
# Batch no: 058, Loss on trainig: 1.1401, Accuracy: 0.6875
# Batch no: 059, Loss on trainig: 1.4028, Accuracy: 0.6406
# Batch no: 060, Loss on trainig: 0.9962, Accuracy: 0.6875
# Batch no: 061, Loss on trainig: 1.2117, Accuracy: 0.6562
# Batch no: 062, Loss on trainig: 1.7439, Accuracy: 0.5469
# Batch no: 063, Loss on trainig: 1.6048, Accuracy: 0.5781
# Batch no: 064, Loss on trainig: 1.1620, Accuracy: 0.6875
# Batch no: 065, Loss on trainig: 1.4735, Accuracy: 0.5312
# Batch no: 066, Loss on trainig: 1.3173, Accuracy: 0.6562
# Batch no: 067, Loss on trainig: 1.2312, Accuracy: 0.6406
# Batch no: 068, Loss on trainig: 0.8645, Accuracy: 0.7500
# Batch no: 069, Loss on trainig: 1.3043, Accuracy: 0.6562
# Batch no: 070, Loss on trainig: 1.0588, Accuracy: 0.7031
# Batch no: 071, Loss on trainig: 1.0745, Accuracy: 0.7344
# Batch no: 072, Loss on trainig: 1.5346, Accuracy: 0.5156
# Batch no: 073, Loss on trainig: 1.2693, Accuracy: 0.6562
# Batch no: 074, Loss on trainig: 1.0122, Accuracy: 0.7188
# Batch no: 075, Loss on trainig: 1.0758, Accuracy: 0.6875
# Batch no: 076, Loss on trainig: 1.7244, Accuracy: 0.5625
# Batch no: 077, Loss on trainig: 1.4085, Accuracy: 0.5625
# Batch no: 078, Loss on trainig: 1.4688, Accuracy: 0.5938
# Batch no: 079, Loss on trainig: 1.5099, Accuracy: 0.6094
# Batch no: 080, Loss on trainig: 1.2211, Accuracy: 0.5312
# Batch no: 081, Loss on trainig: 1.0918, Accuracy: 0.6875
# Batch no: 082, Loss on trainig: 1.3255, Accuracy: 0.5938
# Batch no: 083, Loss on trainig: 1.2838, Accuracy: 0.6406
# Batch no: 084, Loss on trainig: 1.4459, Accuracy: 0.5312
# Batch no: 085, Loss on trainig: 1.2440, Accuracy: 0.6562
# Batch no: 086, Loss on trainig: 1.6983, Accuracy: 0.4844
# Batch no: 087, Loss on trainig: 1.5826, Accuracy: 0.5781
# Batch no: 088, Loss on trainig: 1.1081, Accuracy: 0.7656
# Batch no: 089, Loss on trainig: 1.2156, Accuracy: 0.5469
# Batch no: 090, Loss on trainig: 1.3794, Accuracy: 0.6094
# Batch no: 091, Loss on trainig: 1.2635, Accuracy: 0.6562
# Batch no: 092, Loss on trainig: 1.4429, Accuracy: 0.6094
# Batch no: 093, Loss on trainig: 1.3472, Accuracy: 0.6406
# Batch no: 094, Loss on trainig: 1.4437, Accuracy: 0.5625
# Batch no: 095, Loss on trainig: 1.4530, Accuracy: 0.6094
# Batch no: 096, Loss on trainig: 1.1500, Accuracy: 0.7031
# Batch no: 097, Loss on trainig: 1.2216, Accuracy: 0.6406
# Batch no: 098, Loss on trainig: 1.1871, Accuracy: 0.6719
# Batch no: 099, Loss on trainig: 0.9680, Accuracy: 0.7188
# Batch no: 100, Loss on trainig: 1.8447, Accuracy: 0.5781
# Batch no: 101, Loss on trainig: 1.3831, Accuracy: 0.5781
# Batch no: 102, Loss on trainig: 1.6282, Accuracy: 0.6250
# Epoch: 17/18
# Batch no: 000, Loss on trainig: 1.3843, Accuracy: 0.6406
# Batch no: 001, Loss on trainig: 1.2983, Accuracy: 0.5781
# Batch no: 002, Loss on trainig: 1.2760, Accuracy: 0.6094
# Batch no: 003, Loss on trainig: 1.1756, Accuracy: 0.6875
# Batch no: 004, Loss on trainig: 1.5570, Accuracy: 0.6094
# Batch no: 005, Loss on trainig: 1.6027, Accuracy: 0.6250
# Batch no: 006, Loss on trainig: 1.4263, Accuracy: 0.6094
# Batch no: 007, Loss on trainig: 1.4457, Accuracy: 0.5625
# Batch no: 008, Loss on trainig: 1.1319, Accuracy: 0.6875
# Batch no: 009, Loss on trainig: 1.0865, Accuracy: 0.6406
# Batch no: 010, Loss on trainig: 1.4757, Accuracy: 0.5000
# Batch no: 011, Loss on trainig: 0.9034, Accuracy: 0.7500
# Batch no: 012, Loss on trainig: 1.0977, Accuracy: 0.6406
# Batch no: 013, Loss on trainig: 1.3053, Accuracy: 0.6562
# Batch no: 014, Loss on trainig: 1.4419, Accuracy: 0.5312
# Batch no: 015, Loss on trainig: 1.1107, Accuracy: 0.6250
# Batch no: 016, Loss on trainig: 1.5445, Accuracy: 0.6094
# Batch no: 017, Loss on trainig: 1.2414, Accuracy: 0.6875
# Batch no: 018, Loss on trainig: 1.4846, Accuracy: 0.5938
# Batch no: 019, Loss on trainig: 1.1611, Accuracy: 0.7188
# Batch no: 020, Loss on trainig: 1.3863, Accuracy: 0.6250
# Batch no: 021, Loss on trainig: 1.3211, Accuracy: 0.6250
# Batch no: 022, Loss on trainig: 1.2612, Accuracy: 0.5938
# Batch no: 023, Loss on trainig: 1.2287, Accuracy: 0.6094
# Batch no: 024, Loss on trainig: 1.5836, Accuracy: 0.5156
# Batch no: 025, Loss on trainig: 1.1627, Accuracy: 0.6719
# Batch no: 026, Loss on trainig: 0.9892, Accuracy: 0.6719
# Batch no: 027, Loss on trainig: 0.8765, Accuracy: 0.7344
# Batch no: 028, Loss on trainig: 1.4922, Accuracy: 0.6406
# Batch no: 029, Loss on trainig: 1.4067, Accuracy: 0.5938
# Batch no: 030, Loss on trainig: 1.7953, Accuracy: 0.5469
# Batch no: 031, Loss on trainig: 1.8036, Accuracy: 0.4219
# Batch no: 032, Loss on trainig: 1.2226, Accuracy: 0.6250
# Batch no: 033, Loss on trainig: 0.8950, Accuracy: 0.6875
# Batch no: 034, Loss on trainig: 1.3745, Accuracy: 0.5469
# Batch no: 035, Loss on trainig: 1.6951, Accuracy: 0.5938
# Batch no: 036, Loss on trainig: 1.3756, Accuracy: 0.5938
# Batch no: 037, Loss on trainig: 1.2158, Accuracy: 0.7031
# Batch no: 038, Loss on trainig: 1.2587, Accuracy: 0.6406
# Batch no: 039, Loss on trainig: 1.1243, Accuracy: 0.7031
# Batch no: 040, Loss on trainig: 1.3211, Accuracy: 0.5625
# Batch no: 041, Loss on trainig: 1.6117, Accuracy: 0.5312
# Batch no: 042, Loss on trainig: 1.2425, Accuracy: 0.6250
# Batch no: 043, Loss on trainig: 1.6481, Accuracy: 0.5781
# Batch no: 044, Loss on trainig: 1.0310, Accuracy: 0.7656
# Batch no: 045, Loss on trainig: 1.1337, Accuracy: 0.7031
# Batch no: 046, Loss on trainig: 1.0937, Accuracy: 0.7188
# Batch no: 047, Loss on trainig: 1.2935, Accuracy: 0.6719
# Batch no: 048, Loss on trainig: 1.4957, Accuracy: 0.5781
# Batch no: 049, Loss on trainig: 1.3180, Accuracy: 0.6562
# Batch no: 050, Loss on trainig: 0.8977, Accuracy: 0.6719
# Batch no: 051, Loss on trainig: 1.2235, Accuracy: 0.6719
# Batch no: 052, Loss on trainig: 1.2344, Accuracy: 0.6250
# Batch no: 053, Loss on trainig: 1.4646, Accuracy: 0.6406
# Batch no: 054, Loss on trainig: 1.2614, Accuracy: 0.6562
# Batch no: 055, Loss on trainig: 1.2705, Accuracy: 0.5781
# Batch no: 056, Loss on trainig: 1.3342, Accuracy: 0.6406
# Batch no: 057, Loss on trainig: 1.5212, Accuracy: 0.5625
# Batch no: 058, Loss on trainig: 1.3518, Accuracy: 0.6562
# Batch no: 059, Loss on trainig: 1.5962, Accuracy: 0.5469
# Batch no: 060, Loss on trainig: 1.3427, Accuracy: 0.6250
# Batch no: 061, Loss on trainig: 1.3742, Accuracy: 0.5625
# Batch no: 062, Loss on trainig: 1.5313, Accuracy: 0.5781
# Batch no: 063, Loss on trainig: 1.6192, Accuracy: 0.6250
# Batch no: 064, Loss on trainig: 1.3900, Accuracy: 0.5625
# Batch no: 065, Loss on trainig: 1.2374, Accuracy: 0.6719
# Batch no: 066, Loss on trainig: 1.3364, Accuracy: 0.6562
# Batch no: 067, Loss on trainig: 1.4275, Accuracy: 0.6094
# Batch no: 068, Loss on trainig: 1.4550, Accuracy: 0.6094
# Batch no: 069, Loss on trainig: 1.5065, Accuracy: 0.4844
# Batch no: 070, Loss on trainig: 1.2842, Accuracy: 0.6094
# Batch no: 071, Loss on trainig: 1.2389, Accuracy: 0.7188
# Batch no: 072, Loss on trainig: 1.6186, Accuracy: 0.6094
# Batch no: 073, Loss on trainig: 1.1847, Accuracy: 0.6406
# Batch no: 074, Loss on trainig: 1.1396, Accuracy: 0.6562
# Batch no: 075, Loss on trainig: 1.4955, Accuracy: 0.5625
# Batch no: 076, Loss on trainig: 1.2094, Accuracy: 0.6562
# Batch no: 077, Loss on trainig: 1.4978, Accuracy: 0.5938
# Batch no: 078, Loss on trainig: 0.8930, Accuracy: 0.7656
# Batch no: 079, Loss on trainig: 1.3269, Accuracy: 0.6719
# Batch no: 080, Loss on trainig: 1.2337, Accuracy: 0.6250
# Batch no: 081, Loss on trainig: 1.1454, Accuracy: 0.7031
# Batch no: 082, Loss on trainig: 1.6428, Accuracy: 0.5312
# Batch no: 083, Loss on trainig: 1.3420, Accuracy: 0.4844
# Batch no: 084, Loss on trainig: 1.5587, Accuracy: 0.5781
# Batch no: 085, Loss on trainig: 1.2539, Accuracy: 0.6719
# Batch no: 086, Loss on trainig: 1.2461, Accuracy: 0.6406
# Batch no: 087, Loss on trainig: 0.9906, Accuracy: 0.7188
# Batch no: 088, Loss on trainig: 1.4030, Accuracy: 0.6719
# Batch no: 089, Loss on trainig: 1.6207, Accuracy: 0.5781
# Batch no: 090, Loss on trainig: 1.0426, Accuracy: 0.7188
# Batch no: 091, Loss on trainig: 1.0972, Accuracy: 0.6406
# Batch no: 092, Loss on trainig: 1.3408, Accuracy: 0.6250
# Batch no: 093, Loss on trainig: 1.4737, Accuracy: 0.5312
# Batch no: 094, Loss on trainig: 1.3268, Accuracy: 0.6719
# Batch no: 095, Loss on trainig: 1.1521, Accuracy: 0.6562
# Batch no: 096, Loss on trainig: 1.4069, Accuracy: 0.5625
# Batch no: 097, Loss on trainig: 1.0667, Accuracy: 0.7031
# Batch no: 098, Loss on trainig: 1.2585, Accuracy: 0.6562
# Batch no: 099, Loss on trainig: 1.2226, Accuracy: 0.6562
# Batch no: 100, Loss on trainig: 1.1830, Accuracy: 0.6562
# Batch no: 101, Loss on trainig: 1.6263, Accuracy: 0.5938
# Batch no: 102, Loss on trainig: 0.7430, Accuracy: 0.6667
# Epoch: 18/18
# Batch no: 000, Loss on trainig: 1.3946, Accuracy: 0.6094
# Batch no: 001, Loss on trainig: 1.0634, Accuracy: 0.6562
# Batch no: 002, Loss on trainig: 1.4235, Accuracy: 0.6875
# Batch no: 003, Loss on trainig: 1.0514, Accuracy: 0.6562
# Batch no: 004, Loss on trainig: 1.2163, Accuracy: 0.5781
# Batch no: 005, Loss on trainig: 1.4504, Accuracy: 0.6719
# Batch no: 006, Loss on trainig: 1.2513, Accuracy: 0.5781
# Batch no: 007, Loss on trainig: 1.4499, Accuracy: 0.6406
# Batch no: 008, Loss on trainig: 1.6585, Accuracy: 0.5625
# Batch no: 009, Loss on trainig: 1.6319, Accuracy: 0.5469
# Batch no: 010, Loss on trainig: 1.2175, Accuracy: 0.6875
# Batch no: 011, Loss on trainig: 1.1766, Accuracy: 0.6719
# Batch no: 012, Loss on trainig: 1.5372, Accuracy: 0.6094
# Batch no: 013, Loss on trainig: 1.4284, Accuracy: 0.6250
# Batch no: 014, Loss on trainig: 1.3484, Accuracy: 0.6406
# Batch no: 015, Loss on trainig: 1.4757, Accuracy: 0.5312
# Batch no: 016, Loss on trainig: 1.2162, Accuracy: 0.6094
# Batch no: 017, Loss on trainig: 1.3450, Accuracy: 0.6250
# Batch no: 018, Loss on trainig: 1.1405, Accuracy: 0.6719
# Batch no: 019, Loss on trainig: 1.3767, Accuracy: 0.6406
# Batch no: 020, Loss on trainig: 1.2655, Accuracy: 0.6406
# Batch no: 021, Loss on trainig: 0.8549, Accuracy: 0.7656
# Batch no: 022, Loss on trainig: 1.3193, Accuracy: 0.5625
# Batch no: 023, Loss on trainig: 1.1098, Accuracy: 0.6875
# Batch no: 024, Loss on trainig: 1.1579, Accuracy: 0.7031
# Batch no: 025, Loss on trainig: 1.6575, Accuracy: 0.5312
# Batch no: 026, Loss on trainig: 1.0425, Accuracy: 0.6875
# Batch no: 027, Loss on trainig: 1.5050, Accuracy: 0.5469
# Batch no: 028, Loss on trainig: 1.2505, Accuracy: 0.6562
# Batch no: 029, Loss on trainig: 1.3038, Accuracy: 0.6406
# Batch no: 030, Loss on trainig: 1.2097, Accuracy: 0.6719
# Batch no: 031, Loss on trainig: 1.2612, Accuracy: 0.5781
# Batch no: 032, Loss on trainig: 1.4717, Accuracy: 0.5312
# Batch no: 033, Loss on trainig: 1.5201, Accuracy: 0.5625
# Batch no: 034, Loss on trainig: 1.1744, Accuracy: 0.6719
# Batch no: 035, Loss on trainig: 1.2047, Accuracy: 0.6250
# Batch no: 036, Loss on trainig: 1.0459, Accuracy: 0.7031
# Batch no: 037, Loss on trainig: 1.3175, Accuracy: 0.6094
# Batch no: 038, Loss on trainig: 1.4623, Accuracy: 0.5938
# Batch no: 039, Loss on trainig: 1.8677, Accuracy: 0.5312
# Batch no: 040, Loss on trainig: 0.9962, Accuracy: 0.7031
# Batch no: 041, Loss on trainig: 1.0797, Accuracy: 0.7031
# Batch no: 042, Loss on trainig: 1.2156, Accuracy: 0.6406
# Batch no: 043, Loss on trainig: 1.1110, Accuracy: 0.6406
# Batch no: 044, Loss on trainig: 0.9565, Accuracy: 0.6875
# Batch no: 045, Loss on trainig: 1.6398, Accuracy: 0.5781
# Batch no: 046, Loss on trainig: 0.9295, Accuracy: 0.7500
# Batch no: 047, Loss on trainig: 1.3317, Accuracy: 0.6406
# Batch no: 048, Loss on trainig: 1.0472, Accuracy: 0.7188
# Batch no: 049, Loss on trainig: 1.5341, Accuracy: 0.6250
# Batch no: 050, Loss on trainig: 1.1927, Accuracy: 0.6562
# Batch no: 051, Loss on trainig: 1.3827, Accuracy: 0.5781
# Batch no: 052, Loss on trainig: 1.2140, Accuracy: 0.6562
# Batch no: 053, Loss on trainig: 1.2500, Accuracy: 0.6875
# Batch no: 054, Loss on trainig: 1.4215, Accuracy: 0.6875
# Batch no: 055, Loss on trainig: 1.3443, Accuracy: 0.6562
# Batch no: 056, Loss on trainig: 1.1071, Accuracy: 0.5938
# Batch no: 057, Loss on trainig: 1.1493, Accuracy: 0.6719
# Batch no: 058, Loss on trainig: 1.6210, Accuracy: 0.6250
# Batch no: 059, Loss on trainig: 1.2606, Accuracy: 0.6875
# Batch no: 060, Loss on trainig: 1.5473, Accuracy: 0.5781
# Batch no: 061, Loss on trainig: 1.3205, Accuracy: 0.6562
# Batch no: 062, Loss on trainig: 1.4761, Accuracy: 0.5781
# Batch no: 063, Loss on trainig: 0.9135, Accuracy: 0.7031
# Batch no: 064, Loss on trainig: 1.2297, Accuracy: 0.6875
# Batch no: 065, Loss on trainig: 1.0365, Accuracy: 0.6875
# Batch no: 066, Loss on trainig: 1.5120, Accuracy: 0.5781
# Batch no: 067, Loss on trainig: 1.1360, Accuracy: 0.6562
# Batch no: 068, Loss on trainig: 1.3588, Accuracy: 0.6406
# Batch no: 069, Loss on trainig: 1.2295, Accuracy: 0.5938
# Batch no: 070, Loss on trainig: 1.3818, Accuracy: 0.6094
# Batch no: 071, Loss on trainig: 1.3598, Accuracy: 0.6250
# Batch no: 072, Loss on trainig: 1.2536, Accuracy: 0.5781
# Batch no: 073, Loss on trainig: 1.2940, Accuracy: 0.5938
# Batch no: 074, Loss on trainig: 1.7890, Accuracy: 0.4844
# Batch no: 075, Loss on trainig: 1.2713, Accuracy: 0.5938
# Batch no: 076, Loss on trainig: 1.3473, Accuracy: 0.6406
# Batch no: 077, Loss on trainig: 1.5781, Accuracy: 0.5625
# Batch no: 078, Loss on trainig: 1.0513, Accuracy: 0.7031
# Batch no: 079, Loss on trainig: 1.4266, Accuracy: 0.6250
# Batch no: 080, Loss on trainig: 1.5158, Accuracy: 0.5938
# Batch no: 081, Loss on trainig: 0.9240, Accuracy: 0.6562
# Batch no: 082, Loss on trainig: 1.3810, Accuracy: 0.6250
# Batch no: 083, Loss on trainig: 1.0191, Accuracy: 0.7188
# Batch no: 084, Loss on trainig: 1.4241, Accuracy: 0.6406
# Batch no: 085, Loss on trainig: 1.3350, Accuracy: 0.6250
# Batch no: 086, Loss on trainig: 1.3204, Accuracy: 0.5938
# Batch no: 087, Loss on trainig: 1.4770, Accuracy: 0.5781
# Batch no: 088, Loss on trainig: 1.4652, Accuracy: 0.5000
# Batch no: 089, Loss on trainig: 1.7325, Accuracy: 0.5000
# Batch no: 090, Loss on trainig: 1.4053, Accuracy: 0.6406
# Batch no: 091, Loss on trainig: 1.4914, Accuracy: 0.6094
# Batch no: 092, Loss on trainig: 1.1584, Accuracy: 0.6406
# Batch no: 093, Loss on trainig: 1.6848, Accuracy: 0.5469
# Batch no: 094, Loss on trainig: 1.4375, Accuracy: 0.5469
# Batch no: 095, Loss on trainig: 0.9989, Accuracy: 0.6875
# Batch no: 096, Loss on trainig: 0.9243, Accuracy: 0.7344
# Batch no: 097, Loss on trainig: 1.4770, Accuracy: 0.5781
# Batch no: 098, Loss on trainig: 1.3569, Accuracy: 0.6562
# Batch no: 099, Loss on trainig: 1.2316, Accuracy: 0.6250
# Batch no: 100, Loss on trainig: 1.4165, Accuracy: 0.6094
# Batch no: 101, Loss on trainig: 1.3355, Accuracy: 0.6562
# Batch no: 102, Loss on trainig: 1.0216, Accuracy: 0.7500

# %%
# TODO: Do validation on the test set
#Maintaining a separate validation set is important, 
#so that we can stop the training at the right point and prevent overfitting. 
#Validation is carried out in each epoch immediately after the training loop.
#Since we do not need any gradient computation in the validation process, it is done with torch.no_grad().
#For each validation batch, the inputs and labels are transferred to the GPU ( if cuda is available, else cpu).
#The inputs go through the forwards pass, 
#followed by the loss and accuracy computations for the batch and at the end of the loop, for the whole epoch.

# Validation - No gradient tracking needed
with torch.no_grad():
 
    # Set to evaluation mode
    model.eval()


    # Validation loop
    for j, (inputs, labels) in enumerate(validation_loader):
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
 
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
 
        # Compute loss
        loss = criterion(outputs, labels)
 
        # Compute the total loss for the batch and add it to valid_loss
        valid_loss += loss.item() * inputs.size(0)
 
        # Calculate validation accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
 
        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
 
        # Compute total accuracy in the whole batch and add to valid_acc
        valid_acc += acc.item() * inputs.size(0)
 
        print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
# Out:
# Validation Batch number: 000, Validation: Loss: 0.5003, Accuracy: 0.8281
# Validation Batch number: 001, Validation: Loss: 0.5844, Accuracy: 0.7969
# Validation Batch number: 002, Validation: Loss: 0.6553, Accuracy: 0.8281
# Validation Batch number: 003, Validation: Loss: 0.4439, Accuracy: 0.8750
# Validation Batch number: 004, Validation: Loss: 0.8773, Accuracy: 0.8281
# Validation Batch number: 005, Validation: Loss: 0.3411, Accuracy: 0.9219
# Validation Batch number: 006, Validation: Loss: 0.5510, Accuracy: 0.8594
# Validation Batch number: 007, Validation: Loss: 0.5053, Accuracy: 0.8750
# Validation Batch number: 008, Validation: Loss: 0.5915, Accuracy: 0.8438
# Validation Batch number: 009, Validation: Loss: 0.4701, Accuracy: 0.8906
# Validation Batch number: 010, Validation: Loss: 0.5179, Accuracy: 0.8281
# Validation Batch number: 011, Validation: Loss: 0.4853, Accuracy: 0.8594
# Validation Batch number: 012, Validation: Loss: 0.7008, Accuracy: 0.8200

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# Do validation on the test set
correct,total = 0,0
with torch.no_grad():
    model.eval()
    for data in train_loader:
        images, labels = data
        images, labels = images.to('cuda'), labels.to('cuda')
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy on test images is: %d%%' % (100 * correct / total))
# Out:
# Accuracy on test images is: 81%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
#The class ImageFolder has an attribute class_to_idx which is a dictionary mapping the name of the class to the index (label).
#So, you can access the classes with data.classes and for each class get the label with data.class_to_idx.

#torch.save: Saves a serialized object to disk. This function uses Python’s pickle utility for serialization.
#Models, tensors, and dictionaries of all kinds of objects can be saved using this function.
#torch.save(model, PATH)
#reference:https://pytorch.org/tutorials/beginner/saving_loading_models.html

model.class_to_idx = image_datasets['train'].class_to_idx
torch.save({'structure' :'alexnet',
            'hidden_layer1':120,
             'droupout':0.5,
             'epochs':12,
             'state_dict':model.state_dict(),
             'class_to_idx':model.class_to_idx,
             'optimizer_dict':optimizer.state_dict()},
             'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

#torch.load: Uses pickle’s unpickling facilities to deserialize pickled object files to memory. 
#This function also facilitates the device to load the data into
#When you call torch.load() on a file which contains GPU tensors, 
#those tensors will be loaded to GPU by default. You can call torch.load(.., map_location='cpu')
# and then load_state_dict() to avoid GPU RAM surge when loading a model checkpoint.
##reference:https://pytorch.org/tutorials/beginner/saving_loading_models.html
def loading_the_checkpoint(path='checkpoint.pth'):
    #load the saved file
    checkpoint = torch.load('checkpoint.pth')
    #download pretrained model
    model=models.vgg16(pretrained=True)
    #to freeze parameters
    for param in model.parameters():
        param.requires_grad = False
    #load from checkpoint
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
# TODO: Process a PIL image for use in a PyTorch model
#Image.thumbnail(size, resample=3)
#https://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail
# Crop the center of the image-->.crop((left, top, right, bottom))
#a.transpose().shape = (i[n-1], i[n-2], ... i[1], i[0])
#Refrence on processing the image-->https://stackoverflow.com/questions/55678459/resize-image-in-python
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''

    img = PIL.Image.open(image)

    # Get original dimensions
    original_width, original_height = img.size

    # Find shorter size and create settings to crop shortest side to 256
    if original_width < original_height:
        size=[256, 256**600]
    else: 
        size=[256**600, 256]
        
    img.thumbnail(size)
   

    center = original_width/4, original_height/4
    left, top, right, bottom = center[0]-(244/2), center[1]-(244/2), center[0]+(244/2), center[1]+(244/2)
    img = img.crop((left, top, right, bottom))

    numpy_img = np.array(img)/255 

    # Normalize each color channel
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    numpy_img = (numpy_img-mean)/std
        
    # Set the color to the first channel
    numpy_img = numpy_img.transpose(2, 0, 1)
    
    return numpy_img

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    #img for tensor
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))   
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

imshow(process_image("flowers/test/9/image_06413.jpg"))
imshow(process_image("flowers/test/37/image_03734.jpg"))
imshow(process_image("flowers/test/10/image_07090.jpg"))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, top_k=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    
    image_path: string. Path to image, directly to image and not to folder.
    model: pytorch neural network.
    top_k: integer. The top K classes to be calculated
    
    returns top_probabilities(k), top_labels
    '''
    
    # No need for GPU on this part (just causes problems)
    model.to("cpu")
    
    # Set model to evaluate
    model.eval();

    # Convert image from numpy to torch
    torch_image = torch.from_numpy(np.expand_dims(process_image(image_path), 
                                                  axis=0)).type(torch.FloatTensor).to("cpu")

    # Find probabilities (results) by passing through the function (note the log softmax means that its on a log scale)
    log_probs = model.forward(torch_image)

    # Convert to linear scale
    linear_probs = torch.exp(log_probs)

    # Find the top 5 results
    top_probs, top_labels = linear_probs.topk(top_k)
    
    # Detatch all of the details
    top_probs = np.array(top_probs.detach())[0] # This is not the correct way to do it but the correct way isnt working thanks to cpu/gpu issues so I don't care.
    top_labels = np.array(top_labels.detach())[0]
    
    # Convert to classes
    idx_to_class = {val: key for key, val in    
                                      model.class_to_idx.items()}
    top_labels = [idx_to_class[lab] for lab in top_labels]
    top_flowers = [cat_to_name[lab] for lab in top_labels]
    
    return top_probs, top_labels, top_flowers

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
# Define image path
image_path = "flowers/test/37/image_03734.jpg"

# Set up plot
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)

# Set up title
flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]

# Plot flower
img = process_image(image_path)
imshow(img, ax, title = title_);

# Make prediction
probs, labs, flowers = predict(image_path, model) 

# Plot bar chart
plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show()

# %%
image_path = "flowers/test/9/image_06413.jpg"
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)
flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]
img = process_image(image_path)
imshow(img, ax, title = title_);
probs, labs, flowers = predict(image_path, model) 
plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show()
